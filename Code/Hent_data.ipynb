# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests
import urllib.request as request
from urllib.parse import quote

import ruptures as rpt

from datetime import datetime
from datetime import timedelta
from tqdm import tqdm
import pyodbc 

pd.options.mode.chained_assignment = None

# %%
def get_token():
    refresh_token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....LQK0L0S3NRzL5oEOCr2CUIhc08Bul0NjQzkahB7JsOw'
    try:
        access_token
    except NameError:
        url = "https://api.eloverblik.dk/ThirdPartyApi" + '/api/Token'
        headers = {'Authorization': 'Bearer ' + refresh_token}
        token_response = requests.get(url, headers=headers, timeout=5)
        token_response.raise_for_status()
        token_json = token_response.json()
        access_token = token_json['result']
        timelog = datetime.now() - timedelta(days=2)
    else:
        time_between_insertion = datetime.now() - timelog
        if  time_between_insertion.days > 1:
            url = "https://api.eloverblik.dk/ThirdPartyApi" + '/api/Token'
            headers = {'Authorization': 'Bearer ' + refresh_token}
            token_response = requests.get(url, headers=headers, timeout=5)
            token_response.raise_for_status()
            token_json = token_response.json()
            access_token = token_json['result']
            
            timelog = datetime.now()
    return access_token

def getMeterPoints(Customer):
    ApiKey = "3bb0bb5c-392d-4daa-8b0e-6a675387d08b"
    url = "https://superhub.dk/api/nrgiraadgivning/v2/meteringPoints"
    url = url + "?" + "apikey=" + ApiKey + "&customerKey=" + quote(Customer)
    response = requests.get(url)
    df = pd.json_normalize(response.json()) 
    df['meteringPointId'] = pd.to_numeric(df['meteringPointId'])
    IDs = df['meteringPointId'].to_list()
    return df, IDs

def sql_query(df):
    SERVER = "vsqlmorb"
    PORT = '1433' 
    USER = "pwu-morb"
    PASSWORD = "JGo9822YbQvlcLtx"
    DATABASE = "databox_aftagerknude"

    conn = pyodbc.connect('Driver={SQL Server};'
                        'Server=' + SERVER +';'
                        'Database='+ DATABASE +';'
                        'UID=' + USER +';'
                        'PWD=' + PASSWORD + ';')
    
    df_adr = df['Adresse']
    fejl = []
    dfs = []
    for rows in tqdm(range(df_adr.shape[0])):
        query = """
        SELECT id_lokalid, husnummer, adressebetegnelse
        FROM dar.adresse
        WHERE adressebetegnelse = '{}' 
        """.format(df_adr.iloc[rows])
        chunk = pd.read_sql(query, con=conn) 
        if chunk.empty: fejl.append(df_adr.iloc[rows])
        dfs.append(chunk)
    df = pd.concat(dfs, ignore_index=True)
    #df['ValidTo_reports'] = pd.to_datetime(df['ValidTo_reports'])
    #df = df[df['ValidTo_reports'].dt.date >= date.today()]
    df = df.reset_index()
    fejl = pd.DataFrame(fejl, columns=['Adresse'])
    return df, fejl

def BBR_api1(df):
    SERVER = "vsqlmorb"
    PORT = '1433' 
    USER = "pwu-morb"
    PASSWORD = "JGo9822YbQvlcLtx"
    DATABASE = "databox_aftagerknude"

    conn = pyodbc.connect('Driver={SQL Server};'
                        'Server=' + SERVER +';'
                        'Database='+ DATABASE +';'
                        'UID=' + USER +';'
                        'PWD=' + PASSWORD + ';')
    
    #df, _ = sql_query(df)

    df['areal'] = np.NaN
    df['anvendelseskode'] = np.NaN
    fejl = []
    dfs = []

    for rows in tqdm(range(df.shape[0])):
        query = """
        SELECT byg038samletbygningsareal, byg021bygningensanvendelse, byg007bygningsnummer, byg041bebyggetareal
        FROM bbr.bygning
        WHERE (Husnummer = '{}') AND (registreringtil IS NULL) AND (virkningtil IS NULL) AND (status = 6)
        """.format(df.iloc[rows]['husnummer'])
        chunk = pd.read_sql(query, con=conn) 
        #print(df['adressebetegnelse'].iloc[rows])
        #print(chunk['byg038samletbygningsareal'].head())
        #if chunk.empty: fejl.append(df.iloc[rows])
        #dfs.append(chunk)
        if 'byg038samletbygningsareal' in chunk.columns:
            df['areal'].iloc[rows] = chunk['byg038samletbygningsareal'].dropna().unique().sum()
        
        if pd.to_numeric(chunk['byg041bebyggetareal']).dropna().unique().sum() <= 5:
            df['areal'].iloc[rows] = chunk['byg041bebyggetareal'].dropna().unique().sum()
            
        if 'byg021bygningensanvendelse' in chunk.columns:
            df.at[rows, 'anvendelseskode'] = chunk['byg021bygningensanvendelse'].unique()
    #df = pd.concat(dfs, ignore_index=True)
    #df = df.reset_index()
    return df

def BBR_api2(df):
    SERVER = "vsqlmorb"
    PORT = '1433' 
    USER = "pwu-morb"
    PASSWORD = "JGo9822YbQvlcLtx"
    DATABASE = "databox_aftagerknude"

    conn = pyodbc.connect('Driver={SQL Server};'
                        'Server=' + SERVER +';'
                        'Database='+ DATABASE +';'
                        'UID=' + USER +';'
                        'PWD=' + PASSWORD + ';')
    
    

    for rows in tqdm(df.index[df['areal'] == 0].tolist()):
        query = """
        SELECT enh026enhedenssamledeareal, enh020enhedensanvendelse
        FROM bbr.enhed
        WHERE (id_lokalid = '{}') AND (registreringtil IS NULL) AND (virkningtil IS NULL) AND (status = 6)
        """.format(df.iloc[rows]['id_lokalid'])
        chunk = pd.read_sql(query, con=conn) 
        #print(df['adressebetegnelse'].iloc[rows])
        #print(chunk['byg038samletbygningsareal'].head())
        #if chunk.empty: fejl.append(df.iloc[rows])
        #dfs.append(chunk)
        if 'enh026enhedenssamledeareal' in chunk.columns:
            df['areal'].iloc[rows] = chunk['enh026enhedenssamledeareal'].dropna().unique().sum()
        if 'enh020enhedensanvendelse' in chunk.columns:
            df.at[rows, 'anvendelseskode'] = chunk['enh020enhedensanvendelse'].unique()
    
    for rows in tqdm(df.index[df['areal'] == 0].tolist()):
        query = """
        SELECT enh026enhedenssamledeareal, enh020enhedensanvendelse
        FROM bbr.enhed
        WHERE (id_lokalid = '{}') AND (registreringtil IS NULL) AND (virkningtil IS NULL) AND (status = 6)
        """.format(df.iloc[rows]['husnummer'])
        chunk = pd.read_sql(query, con=conn) 
        #print(df['adressebetegnelse'].iloc[rows])
        #print(chunk['byg038samletbygningsareal'].head())
        #if chunk.empty: fejl.append(df.iloc[rows])
        #dfs.append(chunk)
        if 'enh026enhedenssamledeareal' in chunk.columns:
            df['areal'].iloc[rows] = chunk['enh026enhedenssamledeareal'].dropna().unique().sum()
        if 'enh020enhedensanvendelse' in chunk.columns:
            df.at[rows, 'anvendelseskode'] = chunk['enh020enhedensanvendelse'].unique()
    #df = pd.concat(dfs, ignore_index=True)
    #df = df.reset_index()
    return df

def BBR_api2(df):
    SERVER = "vsqlmorb"
    PORT = '1433'
    USER = "pwu-morb"
    PASSWORD = "JGo9822YbQvlcLtx"
    DATABASE = "databox_aftagerknude"

    conn = pyodbc.connect('Driver={SQL Server};'
                          'Server=' + SERVER + ';'
                          'Database=' + DATABASE + ';'
                          'UID=' + USER + ';'
                          'PWD=' + PASSWORD + ';')

    for rows in tqdm(range(len(df))):
        query = """
        SELECT enh026enhedenssamledeareal, enh020enhedensanvendelse
        FROM bbr.enhed
        WHERE (id_lokalid = '{}') AND (registreringtil IS NULL) AND (virkningtil IS NULL) AND (status = 6)
        """.format(df['id_lokalid'].iloc[rows])
        chunk = pd.read_sql(query, con=conn)
        if 'enh026enhedenssamledeareal' in chunk.columns:
            df.at[rows, 'areal'] = chunk['enh026enhedenssamledeareal'].dropna().sum()
        if 'enh020enhedensanvendelse' in chunk.columns:
            df.at[rows, 'anvendelseskode'] = chunk['enh020enhedensanvendelse'].unique()

    for rows in tqdm(range(len(df))):
        query = """
        SELECT enh026enhedenssamledeareal, enh020enhedensanvendelse
        FROM bbr.enhed
        WHERE (id_lokalid = '{}') AND (registreringtil IS NULL) AND (virkningtil IS NULL) AND (status = 6)
        """.format(df['husnummer'].iloc[rows])
        chunk = pd.read_sql(query, con=conn)
        if 'enh026enhedenssamledeareal' in chunk.columns:
            df.at[rows, 'areal'] = chunk['enh026enhedenssamledeareal'].dropna().sum()
        if 'enh020enhedensanvendelse' in chunk.columns:
            df.at[rows, 'anvendelseskode'] = chunk['enh020enhedensanvendelse'].unique()

    return df


# def BBR_api(df):

#     df, fejl = sql_query(df)

#     username = 'MikkelSchmidt2S4J8@dfdprod01.sys'
#     password = '910Mikkel14!'
#     username = 'BYCKJWQMOJ'

#     payload = ''
#     headers = { 'Accept': 'application/json',
#                 'Content-Type': 'application/json' }

#     csv = df
#     #print(csv)
#     csv['areal'] = np.NaN
#     csv['anvendeleskode'] = np.NaN
#     #print(csv)
    
#     for i in tqdm(range(len(csv))):
#         url = 'https://services.datafordeler.dk/BBR/BBRPublic/1/rest/enhed?username=' + username + '&password=' + password + '&Format=JSON&AdresseIdentificerer=' + str(csv['id_lokalid'].iloc[i])
#         response = requests.get(url, headers=headers)
#         if response.status_code != 200:
#                 response = requests.get(url, headers=headers)
#         if response.status_code == 200:
#             data = response.json()
#             #print(data)
#             df = pd.json_normalize(data,)
#             if 'enh026EnhedensSamledeAreal' in df.columns:
#                 csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#                 csv['anvendeleskode'].iloc[i] = df['enh020EnhedensAnvendelse'].iloc[0]

#         if csv['areal'].iloc[i] == np.NaN:
#             url = 'https://services.datafordeler.dk/BBR/BBRPublic/1/rest/bygning?username=' + username + '&password=' + password + '&Format=JSON&Husnummer=' + str(csv['husnummer'].iloc[i])
#             response = requests.get(url, headers=headers)
#             print('husnummer')
#             print(csv['adressebetegnelse'].iloc[i])
#             if response.status_code != 200:
#                     response = requests.get(url, headers=headers)
#             if response.status_code == 200:
#                 print('kode 200')
#                 data = response.json()
#                 #print(data)
#                 df = pd.json_normalize(data,)
#                 if 'byg038samletbygningsareal' in df.columns:
#                     csv['areal'].iloc[i] = df['byg038samletbygningsareal'].unique().sum()
#                     csv['anvendeleskode'].iloc[i] = df['byg021bygningensanvendelse'].iloc[0]
            
#     return csv, df

    #csv.to_csv('../Data/Master data/' + 'Furesø Kommune1' + '.csv', index=False, mode='w', header=True, encoding='UTF-8')
        #dff = df[df['id_lokalId'] == str(lokalid[0])]


def getMeterReadings(meteringPoints):
    ApiKey = "3bb0bb5c-392d-4daa-8b0e-6a675387d08b"
    From = '31122021'#(datetime.today() - timedelta(days = 1000)).strftime('%d%m%Y')
    To = datetime.today().strftime('%d%m%Y')
    df = pd.DataFrame()
    Fails = 0
    for meter in tqdm(meteringPoints):
        url = "https://superhub.dk/api/nrgiraadgivning/v2/meterreadings"
        url = url + "?" + "apikey=" + ApiKey + "&meteringpointId=" + str(meter) + "&from=" + From + "&to=" + To
        
        response = requests.get(url)
        if response.status_code != 200:
            Fails += 1
            continue
        jso = response.json()

        dff = pd.json_normalize(jso)
        
        if (dff.columns == 'meteringPoints.Production').any():
            df_meter = pd.json_normalize(jso['meteringPoints'], 'Production')
        elif (dff.columns == 'meteringPoints.Consumption').any():
            df_meter = pd.json_normalize(jso['meteringPoints'], 'Consumption') 
        else:
            print(dff.head())
            continue
        df_meter['meter'] = jso['meteringPointId']
        df_meter['Adresse'] = jso['streetName'] + ' ' + jso['buildingNumber'] + ', ' + jso['postcode'] + ' ' + jso['cityName']
        df = pd.concat([df, df_meter], ignore_index=True)
    df['from'] = pd.to_datetime(df['from'], utc=True)
    df['meter'] = pd.to_numeric(df['meter'])
    print('Amount of fails: ' + str(Fails))
    #print(url)
    return df

def csv_individual_meters_business(fromdate):
    access_token = get_token()
    meters = IDs
    df = pd.DataFrame(columns=['målerID', 'Mængde',  'from', 'hour'])
    url = "https://api.eloverblik.dk/ThirdPartyApi" + '/api/MeterData/GetTimeSeries/' + fromdate + '/' + '2023-06-13' + '/Hour'
    for meter in tqdm(meters):
        #print(meter)
        body = """{{"meteringPoints": {{
            "meteringPoint": ["{0}"]
        }}
        }}""".format(meter)
        headers = {'Authorization': 'Bearer ' + access_token,
            'Accept': 'application/json',
            'Content-Type': 'application/json' }

        response = requests.post(url, data=body, headers=headers)
        
        if response.status_code != 200:
            print('response!')
            print(response.status_code)
        if response.status_code == 503 or response.status_code == 429:
            print('sleep')
            time.sleep(60)
            response = requests.post(url, data=body, headers=headers)
            if response.status_code != 200:
                print(response.status_code)
        response.raise_for_status()  # raises exception when not a 2xx response
        
        data = response.json()
        
        if not data['result'][0]['MyEnergyData_MarketDocument']['TimeSeries']:
            print(str(meter) + " List is empty")
            continue

        df_meter = pd.json_normalize(
            data['result'][0]['MyEnergyData_MarketDocument']['TimeSeries'][0]['Period'],
            'Point',
            meta=[['timeInterval', 'start'],['timeInterval', 'end']],
            errors='ignore')
        df_meter['målerID'] = meter
        #df['Måleenhed'] = 'kWh'
        df_meter['From_date']= pd.to_datetime(df_meter['timeInterval.start']).dt.date
        df_meter['To_date']= pd.to_datetime(df_meter['timeInterval.end']).dt.date
        df_meter['Mængde'] = pd.to_numeric(df_meter['out_Quantity.quantity'])
        #df['LY Mængde']=df['Mængde'].shift(365*24)
        df_meter['hour'] = pd.to_numeric(df_meter['position'])
        df_meter['from'] = pd.to_datetime(df_meter.To_date) + pd.to_timedelta(df_meter.hour-1, unit='h')
        df_meter = df_meter[['målerID', 'Mængde',  'from', 'hour']]
        df = pd.concat([df, df_meter], ignore_index=True)
        #df.to_csv('../Data/Individual meters/' + 'Guldborgsund Kommune' + '.csv', index=False, encoding='UTF-8', mode='a')
        
    return df

def get_day_moment(hour) -> str: 
    if 6 <= hour <= 18:
        return 'day'
    return 'night'

def ugeprofil(df):
            dff = df.groupby([df['from'].dt.day_name(locale='da_DK'), df['from'].dt.hour]).mean(numeric_only=True).reset_index(names=['day', 'hour'])
            dff['day_'] = dff['day']
            dff['day_'].replace({
                    "Mandag": 0,
                    "Tirsdag": 1,
                    "Onsdag": 2,
                    "Torsdag": 3,
                    "Fredag": 4,
                    "Lørdag": 5,
                    "Søndag": 6},
                    inplace=True,)
            dff.sort_values(['day_', 'hour'], ascending=True, inplace=True)
            dff['x-axis'] = dff.apply(lambda row: row['day'] + ' kl. ' + str(row['hour']), axis=1)
            return dff

def rupt(tid, df):
    nbkps = 12

    test = df['amount']
    points=np.array(test)
    n= len(points)
    if nbkps == 1:
        nbkps = np.floor(np.round(n/365*4))
    #Changepoint detection with dynamic programming search method
    model = "l1"  
    algo = rpt.Window(width=24*30, model=model, min_size=3, jump=5).fit(points)
    my_bkps = algo.predict(n_bkps=nbkps)

    return my_bkps

def besp():
    df_besp = pd.DataFrame(columns=['Adresse', 'besparelse', 'årligt forbrug', 'last', 'best', 'mean', 'bkps'])
    dfff = pd.DataFrame()
    
    for adr in tqdm(df['Adresse'].unique()):
        dff = df[df['Adresse']==adr]
        #print(adr)
        #print(dff.shape)
        dff['day-moment'] = dff['from'].dt.hour.map(get_day_moment)
        dff = dff.groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first', 'Adresse': 'first'}).reset_index()
        my_bkps = rupt('day', dff)

        value_avg_day = np.zeros(len(dff['amount']))
        #stdd_avg_day  = np.zeros(len(dff['amount']))
        vvvv = np.zeros((len(my_bkps),2),)
        k=0
        j=0
        for i in my_bkps:
            value_avg_day[j:i] = np.mean(dff['amount'][j:i])
            #stdd_avg_day[j:i]  = np.std(dff['amount'][j:i])
            vvvv[k, 0] = np.mean(dff['amount'][j:i])
            vvvv[k, 1] = i
            k += 1
            j=i
        dff['bkps'] = value_avg_day
        #print(dff['bkps'])
        
        if dff['bkps'].iloc[-1] >= dff['bkps'].max():
            df_opti = dff[dff['bkps']==dff['bkps'].iloc[-1]].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
        else:
            df_opti = dff[dff['bkps']==dff['bkps'].min()].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
            k=1
            while df_opti['amount'].mean() <= 0.2:
                dff1 = dff[~(dff['bkps']==dff['bkps'].min())]
                df_opti = dff1[dff1['bkps']==dff1['bkps'].min()].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
                k += 1
                del dff1
                if (k == 10):
                    df_opti = dff[dff['bkps']==dff['bkps'].iloc[-1]].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
                    break
                
        df_norm = dff[dff['bkps']==dff['bkps'].iloc[-1]].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()

        uge = ugeprofil(df_opti)
        uge2 = ugeprofil(df_norm) 
        #print(my_bkps)

        ugg = uge[['day', 'hour', 'amount', 'x-axis']].merge(uge2[['day', 'hour', 'amount']], how='outer', on=['day', 'hour'], suffixes=('_opti', '_now'))
        ugg['besparelse_kwh'] = ugg['amount_now'] - ugg['amount_opti']
        ttt = pd.DataFrame(data={'Adresse': [adr], 
                                 'besparelse': [ugg['besparelse_kwh'].sum()*52], 
                                 'årligt forbrug': [ugg['amount_now'].sum()*52],
                                 'last': df_norm['amount'].mean(),
                                 'best': df_opti['amount'].mean(), 
                                 'mean': dff['amount'].mean(),
                                 'meter': dff['meter'].mean(),
                                 'bkps': 0,
                                 'bkps_value': 0,
                                 'total kwh': dff['amount'].sum()} )
        ttt[['bkps', 'bkps_value']] = ttt[['bkps', 'bkps_value']].astype('object')
        ttt.at[0,'bkps'] = my_bkps
        ttt.at[0,'bkps_value'] = vvvv[:,0]
        df_besp = pd.concat([df_besp,ttt])
        dfff = pd.concat([dfff, dff])

    df_besp = df_besp[df_besp['årligt forbrug'] != 0.0]
    df_besp['%'] = df_besp.apply(lambda row: row['besparelse']/row['årligt forbrug']*100, axis=1)
    return df_besp, dfff

# import holidays

# def besp():
#     df_besp = pd.DataFrame(columns=['Adresse', 'besparelse', 'årligt forbrug', 'last', 'best', 'mean', 'bkps'])
#     dfff = pd.DataFrame()

#     # Get Danish holidays for the relevant year
#     year = 2023
#     dk_holidays = holidays.Denmark(years=year)

#     for adr in tqdm(df['Adresse'].unique()):
#         dff = df[df['Adresse'] == adr]
#         dff['day-moment'] = dff['from'].dt.hour.map(get_day_moment)

#         # Add a column for the week of the year
#         dff['week'] = dff['from'].dt.isocalendar().week

#         # Define vacation weeks
#         vacation_weeks = [7, 8, 42, 51, 52, 1] + list(range(27, 33))

#         # Add a column indicating if the week is a vacation week
#         dff['is_vacation_week'] = dff['week'].isin(vacation_weeks)

#         # Consider holidays, July, and vacation weeks as holidays
#         dff['is_holiday'] = dff['from'].dt.date.isin(dk_holidays) | dff['is_vacation_week']

#         # Filter out data during holidays
#         dff = dff[~dff['is_holiday']]
#         dff = dff.drop(columns=['is_holiday', 'is_vacation_week', 'week'])


#         dff = dff.groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first', 'Adresse': 'first'}).reset_index()
#         my_bkps = rupt('day', dff)

#         value_avg_day = np.zeros(len(dff['amount']))
#         vvvv = np.zeros((len(my_bkps), 2))
#         k = 0
#         j = 0
#         for i in my_bkps:
#             value_avg_day[j:i] = np.mean(dff['amount'][j:i])
#             vvvv[k, 0] = np.mean(dff['amount'][j:i])
#             vvvv[k, 1] = i
#             k += 1
#             j = i
#         dff['bkps'] = value_avg_day

#         if dff['bkps'].iloc[-1] >= dff['bkps'].max():
#             df_opti = dff[dff['bkps'] == dff['bkps'].iloc[-1]].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
#         else:
#             df_opti = dff[dff['bkps'] == dff['bkps'].min()].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
#             k = 1
#             while df_opti['amount'].mean() <= 0.2:
#                 dff1 = dff[~(dff['bkps'] == dff['bkps'].min())]
#                 df_opti = dff1[dff1['bkps'] == dff1['bkps'].min()].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
#                 k += 1
#                 del dff1
#                 if k == 10:
#                     df_opti = dff[dff['bkps'] == dff['bkps'].iloc[-1]].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
#                     break

#         df_norm = dff[dff['bkps'] == dff['bkps'].iloc[-1]].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()

#         uge = ugeprofil(df_opti)
#         uge2 = ugeprofil(df_norm)
#         ugg = uge[['day', 'hour', 'amount', 'x-axis']].merge(uge2[['day', 'hour', 'amount']], how='outer', on=['day', 'hour'], suffixes=('_opti', '_now'))
#         ugg['besparelse_kwh'] = ugg['amount_now'] - ugg['amount_opti']
#         ttt = pd.DataFrame(data={'Adresse': [adr], 
#                                  'besparelse': [ugg['besparelse_kwh'].sum() * 52], 
#                                  'årligt forbrug': [ugg['amount_now'].sum() * 52],
#                                  'last': df_norm['amount'].mean(),
#                                  'best': df_opti['amount'].mean(),
#                                  'mean': dff['amount'].mean(),
#                                  'meter': dff['meter'].mean(),
#                                  'bkps': 0,
#                                  'bkps_value': 0,
#                                  'total kwh': dff['amount'].sum()})
#         ttt[['bkps', 'bkps_value']] = ttt[['bkps', 'bkps_value']].astype('object')
#         ttt.at[0, 'bkps'] = my_bkps
#         ttt.at[0, 'bkps_value'] = vvvv[:, 0]
#         df_besp = pd.concat([df_besp, ttt])
#         dfff = pd.concat([dfff, dff])

#     df_besp = df_besp[df_besp['årligt forbrug'] != 0.0]
#     df_besp['%'] = df_besp.apply(lambda row: row['besparelse'] / row['årligt forbrug'] * 100, axis=1)
#     return df_besp, dfff

# %%
#df_mi = csv_individual_meters_business('2021-12-31')
# Out:
# 100%|██████████| 4/4 [00:18<00:00,  4.69s/it]

# %%
#df_mi = df_mi.rename(columns={'målerID': 'meter', 'Mængde': 'amount', 'end': 'from'})
#df_mi.head()
# Out:
#                 meter  amount                from hour
# 0  571313123200029476    0.14 2021-12-31 00:00:00    1
# 1  571313123200029476    0.13 2021-12-31 01:00:00    2
# 2  571313123200029476    0.13 2021-12-31 02:00:00    3
# 3  571313123200029476    0.11 2021-12-31 03:00:00    4
# 4  571313123200029476    0.11 2021-12-31 04:00:00    5

# %%
#df_mid = df_mi.merge(df, how='outer', left_on='meter', right_on='meteringPointId')
#df_mid['Adresse'] = df_mid['streetName'] + ' ' + df_mid['buildingNumber'] + ', ' + df_mid['postcode'] + ' ' + df_mid['cityName']

# %%
#df_mid.shape
# Out:
# (50756, 10)

# %%
#df_mid.head()
# Out:
#                 meter  amount                from hour     meteringPointId  \
# 0  571313123200029476    0.14 2021-12-31 00:00:00    1  571313123200029476
# 1  571313123200029476    0.13 2021-12-31 01:00:00    2  571313123200029476
# 2  571313123200029476    0.13 2021-12-31 02:00:00    3  571313123200029476
# 3  571313123200029476    0.11 2021-12-31 03:00:00    4  571313123200029476
# 4  571313123200029476    0.11 2021-12-31 04:00:00    5  571313123200029476
#
#      streetName buildingNumber postcode     cityName  \
# 0  Anesmindevej              8     8660  Skanderborg
# 1  Anesmindevej              8     8660  Skanderborg
# 2  Anesmindevej              8     8660  Skanderborg
# 3  Anesmindevej              8     8660  Skanderborg
# 4  Anesmindevej              8     8660  Skanderborg
#
#                             Adresse
# 0  Anesmindevej 8, 8660 Skanderborg
# 1  Anesmindevej 8, 8660 Skanderborg
# 2  Anesmindevej 8, 8660 Skanderborg
# 3  Anesmindevej 8, 8660 Skanderborg
# 4  Anesmindevej 8, 8660 Skanderborg

# %%
#token = get_token()
#token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....HWvNGukVGsbmbps_lS39NNqZB9_N8R3J94sLCV0hvME'

# %%
kunde = 'Rebild Kommune'
df, IDs = getMeterPoints(kunde)
print(IDs)
df.head()
# Out:
# [571313104402854516, 571313104402605132, 571313104402647347, 571313104402365524, 571313104402012459, 571313104402541782, 571313104402125357, 571313104402126231, 571313104402141838, 571313104402141975, 571313104402143085, 571313104402143221, 571313104402269884, 571313104402365845, 571313104402541492, 571313104402541508, 571313104402647354, 571313104490368711, 570715000001369321, 570715000001511966, 570715000001550880, 571313104402007387, 571313104402012398, 571313104402012862, 571313104402013876, 571313104402035144, 571313104402035311, 571313104402052639, 571313104402054336, 571313104402056545, 571313104402057344, 571313104402057948, 571313104402059454, 571313104402059522, 571313104402060672, 571313104402067282, 571313104402067725, 571313104402070060, 571313104402070077, 571313104402072347, 571313104402072408, 571313104402084999, 571313104402098217, 571313104402101856, 571313104402102228, 571313104402102235, 571313104402102471, 571313104402102563, 571313104402103133, 571313104402106042, 571313104402113552, 571313104402130092, 571313104402130689, 571313104402135295, 571313104402141678, 571313104402141845, 571313104402142156, 571313104402142262, 571313104402150953, 571313104402151653, 571313104402171248, 571313104402171262, 571313104402175857, 571313104402176175, 571313104402206698, 571313104402211401, 571313104402216697, 571313104402216710, 571313104402217229, 571313104402218912, 571313104402220182, 571313104402224760, 571313104402226832, 571313104402231706, 571313104402232185, 571313104402232284, 571313104402248049, 571313104402255672, 571313104402255771, 571313104402255788, 571313104402255801, 571313104402266784, 571313104402266791, 571313104402271160, 571313104402271474, 571313104402271559, 571313104402271870, 571313104402272471, 571313104402272754, 571313104402280407, 571313104402280759, 571313104402283040, 571313104402294398, 571313104402316281, 571313104402318414, 571313104402320172, 571313104402328949, 571313104402340019, 571313104402342242, 571313104402342570, 571313104402343744, 571313104402351657, 571313104402358908, 571313104402366569, 571313104402366767, 571313104402368570, 571313104402375325, 571313104402384419, 571313104402385751, 571313104402386116, 571313104402389278, 571313104402399369, 571313104402428328, 571313104402432271, 571313104402443314, 571313104402445004, 571313104402445028, 571313104402452552, 571313104402454013, 571313104402454174, 571313104402457724, 571313104402458899, 571313104402459353, 571313104402460779, 571313104402461608, 571313104402461622, 571313104402462353, 571313104402462360, 571313104402464135, 571313104402466238, 571313104402466429, 571313104402466832, 571313104402467358, 571313104402467761, 571313104402468102, 571313104402468379, 571313104402469420, 571313104402470891, 571313104402494552, 571313104402495498, 571313104402500642, 571313104402502226, 571313104402515745, 571313104402516094, 571313104402519033, 571313104402524013, 571313104402526284, 571313104402526987, 571313104402527618, 571313104402540211, 571313104402541614, 571313104402541805, 571313104402542925, 571313104402542932, 571313104402543939, 571313104402544431, 571313104402544790, 571313104402544851, 571313104402545971, 571313104402546046, 571313104402546053, 571313104402549580, 571313104402559022, 571313104402559039, 571313104402572328, 571313104402607624, 571313104402607631, 571313104402610860, 571313104402621620, 571313104402622047, 571313104402626854, 571313104402626861, 571313104402626908, 571313104402627219, 571313104402630998, 571313104402638178, 571313104402638437, 571313104402639984, 571313104402645220, 571313104402646005, 571313104402648924, 571313104402651078, 571313104402652136, 571313104402652143, 571313104402652150, 571313104402652167, 571313104402652174, 571313104402652181, 571313104402652624, 571313104402660186, 571313104402664634, 571313104402667222, 571313104402669387, 571313104402669646, 571313104402683482, 571313104402695386, 571313104402695393, 571313104402697212, 571313104402697243, 571313104402697427, ...
#       meteringPointId      streetName buildingNumber postcode  cityName
# 0  571313104402854516     Bavnebakken            105     9530  Støvring
# 1  571313104402605132      Mastrupvej             65     9530  Støvring
# 2  571313104402647347  Himmerlandsvej             42     9520  Skørping
# 3  571313104402365524         Nibevej           164A     9530  Støvring
# 4  571313104402012459        Fræervej              8     9520  Skørping

# %%
df = getMeterReadings(IDs)
# Out:
#   0%|          | 0/301 [00:00<?, ?it/s]
# 100%|██████████| 301/301 [05:14<00:00,  1.05s/it]
# Amount of fails: 0

# %%
#df = df_mid[['meter', 'amount', 'from', 'Adresse']]
#df[df['Adresse']=='Øster Kærvej 16, 9700 Brønderslev'].head()

# %%
#df.tail()

# %%
df['day-moment'] = df['from'].dt.hour.map(get_day_moment)

# %%
df_besp, dff = besp()
dff['meter'] = pd.to_numeric(dff['meter'])
df_besp.head()
# Out:
# 100%|██████████| 267/267 [09:35<00:00,  2.15s/it]
#                             Adresse    besparelse  årligt forbrug       last  \
# 0    Bavnebakken 105, 9530 Støvring  74499.988333   201162.411667  22.770529
# 0      Mastrupvej 65, 9530 Støvring      0.000000     1931.453333   0.222204
# 0  Himmerlandsvej 42, 9520 Skørping   2838.940000     7138.300000   0.813537
# 0       Nibevej 164A, 9530 Støvring      0.000000     7146.031056   0.816746
# 0         Fræervej 8, 9520 Skørping      0.000000     3209.266667   0.395091
#
#         best       mean                                               bkps  \
# 0  14.414443  23.229540  [1710, 2380, 2820, 3505, 4425, 5730, 8510, 898...
# 0   0.222204   0.537060  [3040, 3700, 4455, 5415, 5980, 6760, 8345, 899...
# 0   0.491187   0.831885  [1165, 1730, 3135, 4390, 7880, 8410, 10005, 10...
# 0   0.816746   0.816746                                            [15383]
# 0   0.395091   0.217133  [2495, 3260, 3695, 5100, 7950, 8625, 9135, 106...
#
#           meter                                         bkps_value  total kwh  \
# 0  5.713131e+17  [27.978280701754386, 26.891000000000002, 19.07...  357340.01
# 0  5.713131e+17  [1.3755493421052631, 0.895090909090909, 0.2978...    8261.59
# 0  5.713131e+17  [1.325364806866953, 0.7988318584070797, 1.1408...   12796.89
# 0  5.713131e+17                                [0.816745758304622]   12564.00
# 0  5.713131e+17  [0.19850901803607213, 0.32881045751633986, 0.1...    3340.15
#
#            %
# 0  37.034746
# 0   0.000000
# 0  39.770534
# 0   0.000000
# 0   0.000000

# %%
df_sql, _ = sql_query(df_besp)
# Out:
#   0%|          | 0/266 [00:00<?, ?it/s]
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   0%|          | 1/266 [00:00<01:13,  3.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 2/266 [00:00<01:05,  4.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 3/266 [00:00<01:10,  3.75it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 4/266 [00:01<01:04,  4.09it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 5/266 [00:01<01:08,  3.78it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 6/266 [00:01<01:03,  4.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 7/266 [00:01<01:03,  4.09it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 8/266 [00:01<01:00,  4.29it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 9/266 [00:02<00:59,  4.31it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 10/266 [00:02<01:07,  3.80it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 11/266 [00:02<01:11,  3.59it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 12/266 [00:03<01:13,  3.47it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 13/266 [00:03<01:14,  3.41it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▌         | 14/266 [00:03<01:15,  3.36it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 15/266 [00:04<01:14,  3.35it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 16/266 [00:04<01:11,  3.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▋         | 17/266 [00:04<01:05,  3.77it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 18/266 [00:04<01:12,  3.44it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 19/266 [00:05<01:13,  3.38it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 20/266 [00:05<01:13,  3.34it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 21/266 [00:05<01:13,  3.32it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 22/266 [00:06<01:14,  3.30it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▊         | 23/266 [00:06<01:13,  3.29it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 24/266 [00:06<01:14,  3.26it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 25/266 [00:07<01:13,  3.28it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|▉         | 26/266 [00:07<01:13,  3.27it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|█         | 27/266 [00:07<01:13,  3.26it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 28/266 [00:07<01:07,  3.55it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 29/266 [00:08<01:02,  3.78it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█▏        | 30/266 [00:08<01:02,  3.75it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 31/266 [00:08<01:05,  3.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 32/266 [00:08<01:00,  3.89it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 33/266 [00:09<01:02,  3.73it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 34/266 [00:09<01:05,  3.53it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 35/266 [00:09<01:04,  3.59it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▎        | 36/266 [00:10<01:08,  3.35it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▍        | 37/266 [00:10<01:08,  3.33it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▍        | 38/266 [00:10<01:09,  3.29it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▍        | 39/266 [00:10<01:02,  3.64it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▌        | 40/266 [00:11<01:10,  3.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▌        | 41/266 [00:11<01:03,  3.56it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▌        | 42/266 [00:11<01:04,  3.45it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▌        | 43/266 [00:12<00:58,  3.80it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 44/266 [00:12<00:58,  3.81it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 45/266 [00:12<00:53,  4.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 46/266 [00:12<00:59,  3.68it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 47/266 [00:13<00:56,  3.86it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 48/266 [00:13<00:59,  3.65it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 49/266 [00:13<00:55,  3.89it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▉        | 50/266 [00:14<01:11,  3.03it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▉        | 51/266 [00:14<01:07,  3.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|█▉        | 52/266 [00:14<01:01,  3.50it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|█▉        | 53/266 [00:14<00:54,  3.88it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|██        | 54/266 [00:15<00:53,  3.94it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██        | 55/266 [00:15<00:49,  4.24it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██        | 56/266 [00:15<00:50,  4.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██▏       | 57/266 [00:15<00:47,  4.40it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 58/266 [00:15<00:47,  4.42it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 59/266 [00:16<00:47,  4.33it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 60/266 [00:16<00:52,  3.94it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 61/266 [00:16<00:55,  3.68it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 62/266 [00:17<00:57,  3.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▎       | 63/266 [00:17<00:54,  3.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▍       | 64/266 [00:17<00:49,  4.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▍       | 65/266 [00:17<00:51,  3.89it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▍       | 66/266 [00:18<00:54,  3.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▌       | 67/266 [00:18<00:56,  3.54it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▌       | 68/266 [00:18<00:57,  3.47it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▌       | 69/266 [00:18<00:54,  3.63it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▋       | 70/266 [00:19<00:53,  3.64it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 71/266 [00:19<00:55,  3.54it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 72/266 [00:19<00:56,  3.42it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 73/266 [00:20<00:57,  3.38it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 74/266 [00:20<00:57,  3.34it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 75/266 [00:20<01:09,  2.75it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▊       | 76/266 [00:21<01:06,  2.86it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▉       | 77/266 [00:21<01:03,  2.99it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▉       | 78/266 [00:21<01:01,  3.07it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|██▉       | 79/266 [00:22<00:59,  3.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|███       | 80/266 [00:22<00:58,  3.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|███       | 81/266 [00:22<01:03,  2.91it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███       | 82/266 [00:23<01:01,  3.00it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███       | 83/266 [00:23<00:59,  3.07it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 84/266 [00:23<00:58,  3.13it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 85/266 [00:24<00:57,  3.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 86/266 [00:24<00:56,  3.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 87/266 [00:24<00:55,  3.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 88/266 [00:25<00:55,  3.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 89/266 [00:25<01:10,  2.50it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▍      | 90/266 [00:26<01:10,  2.48it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▍      | 91/266 [00:26<01:21,  2.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▍      | 92/266 [00:27<01:13,  2.38it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▍      | 93/266 [00:27<01:05,  2.62it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▌      | 94/266 [00:27<01:13,  2.36it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 95/266 [00:28<01:05,  2.61it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 96/266 [00:28<01:10,  2.41it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▋      | 97/266 [00:28<01:06,  2.54it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 98/266 [00:29<01:07,  2.50it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 99/266 [00:29<00:58,  2.84it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 100/266 [00:29<00:54,  3.05it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 101/266 [00:30<00:53,  3.10it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 102/266 [00:30<00:52,  3.13it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▊      | 103/266 [00:30<00:51,  3.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▉      | 104/266 [00:31<00:46,  3.50it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▉      | 105/266 [00:31<00:43,  3.74it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|███▉      | 106/266 [00:31<00:40,  3.96it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|████      | 107/266 [00:31<00:40,  3.90it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████      | 108/266 [00:31<00:37,  4.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████      | 109/266 [00:32<00:40,  3.83it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████▏     | 110/266 [00:32<00:38,  4.00it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  42%|████▏     | 111/266 [00:32<00:40,  3.85it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  42%|████▏     | 112/266 [00:33<00:42,  3.63it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  42%|████▏     | 113/266 [00:33<00:43,  3.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  43%|████▎     | 114/266 [00:33<00:44,  3.42it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  43%|████▎     | 115/266 [00:33<00:45,  3.35it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  44%|████▎     | 116/266 [00:34<00:44,  3.37it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  44%|████▍     | 117/266 [00:34<00:40,  3.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  44%|████▍     | 118/266 [00:34<00:41,  3.56it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  45%|████▍     | 119/266 [00:35<00:42,  3.44it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  45%|████▌     | 120/266 [00:35<00:42,  3.41it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  45%|████▌     | 121/266 [00:35<00:43,  3.34it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  46%|████▌     | 122/266 [00:36<00:43,  3.32it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  46%|████▌     | 123/266 [00:36<00:43,  3.31it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  47%|████▋     | 124/266 [00:36<00:39,  3.59it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  47%|████▋     | 125/266 [00:36<00:36,  3.88it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  47%|████▋     | 126/266 [00:36<00:35,  3.97it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  48%|████▊     | 127/266 [00:37<00:34,  3.97it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  48%|████▊     | 128/266 [00:37<00:37,  3.63it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  48%|████▊     | 129/266 [00:37<00:38,  3.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  49%|████▉     | 130/266 [00:38<00:39,  3.49it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  49%|████▉     | 131/266 [00:38<00:39,  3.40it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  50%|████▉     | 132/266 [00:38<00:43,  3.07it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  50%|█████     | 133/266 [00:39<00:51,  2.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  50%|█████     | 134/266 [00:40<01:15,  1.74it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# ...
#   chunk = pd.read_sql(query, con=conn)
#  83%|████████▎ | 222/266 [01:07<00:12,  3.47it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  84%|████████▍ | 223/266 [01:07<00:12,  3.43it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  84%|████████▍ | 224/266 [01:07<00:11,  3.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  85%|████████▍ | 225/266 [01:08<00:11,  3.58it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  85%|████████▍ | 226/266 [01:08<00:11,  3.50it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  85%|████████▌ | 227/266 [01:08<00:11,  3.40it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  86%|████████▌ | 228/266 [01:08<00:10,  3.75it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  86%|████████▌ | 229/266 [01:09<00:09,  3.85it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  86%|████████▋ | 230/266 [01:09<00:09,  3.81it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  87%|████████▋ | 231/266 [01:09<00:09,  3.57it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  87%|████████▋ | 232/266 [01:10<00:09,  3.54it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  88%|████████▊ | 233/266 [01:10<00:09,  3.44it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  88%|████████▊ | 234/266 [01:10<00:10,  3.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  88%|████████▊ | 235/266 [01:11<00:09,  3.13it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  89%|████████▊ | 236/266 [01:11<00:09,  3.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  89%|████████▉ | 237/266 [01:11<00:09,  3.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  89%|████████▉ | 238/266 [01:12<00:08,  3.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  90%|████████▉ | 239/266 [01:12<00:08,  3.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  90%|█████████ | 240/266 [01:12<00:08,  3.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  91%|█████████ | 241/266 [01:12<00:07,  3.23it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  91%|█████████ | 242/266 [01:13<00:07,  3.30it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  91%|█████████▏| 243/266 [01:13<00:06,  3.56it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  92%|█████████▏| 244/266 [01:13<00:06,  3.46it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  92%|█████████▏| 245/266 [01:14<00:05,  3.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  92%|█████████▏| 246/266 [01:14<00:05,  3.68it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  93%|█████████▎| 247/266 [01:14<00:04,  3.83it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  93%|█████████▎| 248/266 [01:14<00:04,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  94%|█████████▎| 249/266 [01:15<00:04,  3.92it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  94%|█████████▍| 250/266 [01:15<00:04,  3.69it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  94%|█████████▍| 251/266 [01:15<00:03,  3.87it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  95%|█████████▍| 252/266 [01:15<00:03,  4.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  95%|█████████▌| 253/266 [01:16<00:03,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  95%|█████████▌| 254/266 [01:16<00:02,  4.09it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  96%|█████████▌| 255/266 [01:16<00:02,  4.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  96%|█████████▌| 256/266 [01:16<00:02,  3.99it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 257/266 [01:17<00:02,  3.69it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 258/266 [01:17<00:01,  4.05it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 259/266 [01:17<00:01,  4.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 260/266 [01:17<00:01,  3.90it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 261/266 [01:18<00:01,  3.69it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 262/266 [01:18<00:01,  3.56it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▉| 263/266 [01:18<00:00,  3.46it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▉| 264/266 [01:18<00:00,  3.83it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# 100%|█████████▉| 265/266 [01:19<00:00,  3.94it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# 100%|██████████| 266/266 [01:19<00:00,  3.35it/s]

# %%
df_sql.head()
# Out:
#    index                            id_lokalid  \
# 0      0  ff80b984-bcf0-4cd1-a58c-6c45827f2dd8
# 1      1  0a3f50c9-6955-32b8-e044-0003ba298018
# 2      2  73f1b73e-3255-4977-a090-f7b10900c03e
# 3      3  c92406fe-ebf7-40ae-8f9b-551a88ffc9e1
# 4      4  dd6cd5ba-02a3-4771-bd0a-ab3d75376732
#
#                               husnummer                 adressebetegnelse
# 0  0a3f509b-bc56-32b8-e044-0003ba298018    Bavnebakken 105, 9530 Støvring
# 1  0a3f509b-c9ce-32b8-e044-0003ba298018      Mastrupvej 65, 9530 Støvring
# 2  0a3f509b-ad4d-32b8-e044-0003ba298018  Himmerlandsvej 42, 9520 Skørping
# 3  0a3f509b-b504-32b8-e044-0003ba298018          Skovvej 2, 9575 Terndrup
# 4  ab59ee88-da8a-4371-a7e1-055cab0d7199         Grønnegade 1A, 9574 Bælum

# %%
csv = BBR_api1(df_sql)
# Out:
#   0%|          | 0/259 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   0%|          | 1/259 [00:03<16:07,  3.75s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 11/259 [00:03<01:03,  3.92it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 21/259 [00:03<00:27,  8.68it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 29/259 [00:04<00:17, 13.05it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▌        | 39/259 [00:04<00:10, 20.30it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▉        | 49/259 [00:04<00:07, 28.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 60/259 [00:04<00:05, 38.91it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 71/259 [00:04<00:03, 49.61it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███▏      | 81/259 [00:04<00:03, 58.04it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 92/259 [00:04<00:02, 68.31it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|███▉      | 103/259 [00:04<00:02, 77.25it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  44%|████▍     | 114/259 [00:04<00:01, 84.23it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  48%|████▊     | 125/259 [00:05<00:01, 71.36it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  52%|█████▏    | 135/259 [00:05<00:01, 76.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  56%|█████▌    | 144/259 [00:05<00:01, 78.91it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# ...
#   chunk = pd.read_sql(query, con=conn)
#  80%|████████  | 208/259 [00:05<00:00, 114.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  85%|████████▌ | 221/259 [00:05<00:00, 117.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  90%|████████▉ | 233/259 [00:06<00:00, 95.69it/s] C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  95%|█████████▍| 245/259 [00:06<00:00, 100.98it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▉| 256/259 [00:06<00:00, 102.30it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# 100%|██████████| 259/259 [00:06<00:00, 40.39it/s]

# %%
#csv.drop_duplicates(subset=['adressebetegnelse','areal']).sort_values('areal').head(60)

# %%
csv["Anvendelse"] = csv["anvendelseskode"].astype(str)
csv["Anvendelse"].replace(
    {
        "110": "Stuehus til landbrugsejendom",
        "120": "Fritliggende enfamiliehus",
        "121": "Sammenbygget enfamiliehus",
        "122": "Fritliggende enfamiliehus i tæt-lav bebyggelse",
        "130": "Række-, kæde-, eller dobbelthus",
        "131": "Række-, kæde- og klyngehus",
        "132": "Dobbelthus",
        "140": "Etagebolig-bygning, flerfamiliehus eller to-familiehus",
        "150": "Kollegium",
        "160": "Boligbygning til døgninstitution",
        "185": "Anneks i tilknytning til helårsbolig",
        "190": "Anden helårsbeboelse",
        "210": "Erhvervsmæssig produktion vedrørende landbrug, gartneri, råstofudvinding o. lign",
        "211": "Stald til svin",
        "212": "Stald til kvæg, får mv.",
        "213": "Stald til fjerkræ",
        "214": "Minkhal",
        "215": "Væksthus",
        "216": "Lade til foder, afgrøder mv.",
        "217": "Maskinhus, garage mv.",
        "218": "Lade til halm, hø mv.",
        "219": "Anden bygning til landbrug mv.",
        "220": "Erhvervsmæssig produktion vedrørende industri, håndværk m.v.",
        "221": "Industri med integreret produktionsapparat",
        "222": "Industri uden integreret produktionsapparat ",
        "223": "Værksted",
        "229": "Anden til produktion",
        "230": "El-, gas-, vand- eller varmeværk, forbrændingsanstalt m.v.",
        "231": "Energiproduktion",
        "232": "Forsyning- og energidistribution",
        "233": "Vandforsyning",
        "234": "Til håndtering af affald og spildevand",
        "239": "Anden til energiproduktion og -distribution",
        "290": "Anden til landbrug, industri etc.",
        "310": "Transport- og garageanlæg",
        "311": "Jernbane- og busdrift",
        "312": "Luftfart",
        "313": "Parkering- og transportanlæg",
        "314": "Parkering af flere end to køretøjer i tilknytning til boliger",
        "315": "Havneanlæg",
        "319": "Andet transportanlæg",
        "320": "Til kontor, handel, lager, herunder offentlig administration",
        "321": "Kontor",
        "322": "Detailhandel",
        "323": "Lager",
        "324": "Butikscenter",
        "325": "Tankstation",
        "329": "Anden til kontor, handel og lager",
        "330": "Til hotel, restaurant, vaskeri, frisør og anden servicevirksomhed",
        "331": "Hotel, kro eller konferencecenter med overnatning",
        "332": "Bed & breakfast mv.",
        "333": "Restaurant, café og konferencecenter uden overnatning",
        "334": "Privat servicevirksomhed som frisør, vaskeri, netcafé mv.",
        "339": "Anden til serviceerhverv",
        "390": "Anden til transport, handel etc",
        "410": "Biograf, teater, erhvervsmæssig udstilling, bibliotek, museum, kirke o. lign.",
        "411": "Biograf, teater, koncertsted mv.",
        "412": "Museum",
        "413": "Bibliotek",
        "414": "Kirke eller anden til trosudøvelse for statsanerkendte trossamfund",
        "415": "Forsamlingshus",
        "416": "Forlystelsespark",
        "419": "Anden til kulturelle formål",
        "420": "Undervisning og forskning (skole, gymnasium, forskningslabratorium o.lign.).",
        "421": "Grundskole",
        "422": "Universitet",
        "429": "Anden til undervisning og forskning",
        "430": "Hospital, sygehjem, fødeklinik o. lign.",
        "431": "Hospital og sygehus",
        "432": "Hospice, behandlingshjem mv.",
        "433": "Sundhedscenter, lægehus, fødeklinik mv.",
        "439": "Anden til sundhedsformål",
        "440": "Daginstitution",
        "441": "Daginstitution",
        "442": "Servicefunktion på døgninstitution",
        "443": "Kaserne",
        "444": "Fængsel, arresthus mv.",
        "449": "Anden til institutionsformål",
        "490": "Anden institution, herunder kaserne, fængsel o. lign.",
        "510": "Sommerhus",
        "520": "Feriekoloni, vandrehjem o.lign. bortset fra sommerhus",
        "521": "Feriecenter, center til campingplads mv.",
        "522": "Ferielejligheder til erhvervsmæssig udlejning",
        "523": "Ferielejligheder til eget brug",
        "529": "Anden til ferieformål",
        "530": "I forbindelse med idrætsudøvelse (klubhus, idrætshal, svømmehal o. lign.)",
        "531": "Klubhus i forbindelse med fritid og idræt",
        "532": "Svømmehal",
        "533": "Idrætshal",
        "534": "Tribune i forbindelse med stadion",
        "535": "Til træning og opstaldning af heste",
        "539": "Anden til idrætformål",
        "540": "Kolonihavehus",
        "585": "Anneks i tilknytning til fritids- og sommerhus",
        "590": "Anden til fritidsformål",
        "910": "Garage (med plads til et eller to køretøjer)",
        "920": "Carport",
        "930": "Udhus",
        "940": "Drivhus",
        "950": "Fritliggende overdækning",
        "960": "Fritliggende udestue",
        "970": "Tiloversbleven landbrugsbygning",
        "990": "Faldefærdig bygning",
        "999": "Ukendt bygning",
    },
    inplace=True,
)

# %%
csvv = BBR_api2(csv.drop_duplicates(subset=['adressebetegnelse','areal']))
# Out:
#   0%|          | 0/167 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 1/167 [00:01<05:03,  1.83s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 2/167 [00:03<04:46,  1.74s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 3/167 [00:05<05:33,  2.03s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 4/167 [00:07<05:04,  1.87s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 5/167 [00:09<04:41,  1.74s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▎         | 6/167 [00:11<04:57,  1.85s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 7/167 [00:12<04:49,  1.81s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 8/167 [00:14<04:58,  1.88s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▌         | 9/167 [00:16<04:45,  1.81s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 10/167 [00:18<04:45,  1.82s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 11/167 [00:19<04:35,  1.76s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 12/167 [00:21<04:36,  1.79s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 13/167 [00:23<04:33,  1.78s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 14/167 [00:25<04:18,  1.69s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 15/167 [00:26<04:11,  1.65s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|▉         | 16/167 [00:28<04:03,  1.61s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|█         | 17/167 [00:29<04:12,  1.68s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 18/167 [00:31<04:17,  1.73s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█▏        | 19/167 [00:33<04:18,  1.75s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 20/167 [00:35<04:22,  1.79s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 21/167 [00:37<04:25,  1.82s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 22/167 [00:39<04:16,  1.77s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▍        | 23/167 [00:40<04:18,  1.79s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▍        | 24/167 [00:42<04:12,  1.77s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▍        | 25/167 [00:44<04:21,  1.84s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▌        | 26/167 [00:46<04:09,  1.77s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▌        | 27/167 [00:48<04:11,  1.79s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 28/167 [00:49<04:00,  1.73s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 29/167 [00:51<04:01,  1.75s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 30/167 [00:53<03:56,  1.73s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▊        | 31/167 [00:54<03:46,  1.66s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▉        | 32/167 [00:56<03:35,  1.60s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|█▉        | 33/167 [00:57<03:25,  1.53s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|██        | 34/167 [00:59<03:47,  1.71s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██        | 35/167 [01:01<03:39,  1.66s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 36/167 [01:03<03:56,  1.81s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 37/167 [01:04<03:45,  1.73s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 38/167 [01:06<03:49,  1.78s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 39/167 [01:08<03:42,  1.74s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▍       | 40/167 [01:10<03:39,  1.73s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▍       | 41/167 [01:12<03:57,  1.88s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▌       | 42/167 [01:13<03:42,  1.78s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▌       | 43/167 [01:15<03:51,  1.87s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▋       | 44/167 [01:17<03:45,  1.84s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 45/167 [01:19<03:53,  1.91s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 46/167 [01:21<03:37,  1.80s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 47/167 [01:23<03:39,  1.83s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▊       | 48/167 [01:24<03:31,  1.77s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▉       | 49/167 [01:26<03:40,  1.87s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|██▉       | 50/167 [01:28<03:26,  1.77s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███       | 51/167 [01:30<03:37,  1.88s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███       | 52/167 [01:33<04:15,  2.22s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 53/167 [01:37<05:24,  2.84s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 54/167 [01:40<05:17,  2.81s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 55/167 [01:45<06:10,  3.31s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▎      | 56/167 [01:47<05:39,  3.06s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▍      | 57/167 [01:49<05:03,  2.76s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▍      | 58/167 [01:51<04:26,  2.45s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▌      | 59/167 [01:54<04:39,  2.59s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 60/167 [01:55<04:04,  2.29s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 61/167 [01:57<03:50,  2.18s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 62/167 [01:59<03:34,  2.04s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 63/167 [02:01<03:37,  2.09s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 64/167 [02:03<03:18,  1.92s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▉      | 65/167 [02:05<03:12,  1.88s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|███▉      | 66/167 [02:06<03:00,  1.79s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|████      | 67/167 [02:08<03:01,  1.81s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████      | 68/167 [02:10<02:55,  1.77s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████▏     | 69/167 [02:12<03:09,  1.94s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  42%|████▏     | 70/167 [02:14<02:56,  1.82s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  43%|████▎     | 71/167 [02:16<03:08,  1.96s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  43%|████▎     | 72/167 [02:17<02:56,  1.86s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  44%|████▎     | 73/167 [02:19<02:53,  1.84s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  44%|████▍     | 74/167 [02:21<02:42,  1.75s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  45%|████▍     | 75/167 [02:23<02:44,  1.78s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  46%|████▌     | 76/167 [02:24<02:34,  1.70s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  46%|████▌     | 77/167 [02:26<02:34,  1.72s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  47%|████▋     | 78/167 [02:28<02:51,  1.92s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  47%|████▋     | 79/167 [02:30<02:38,  1.81s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  48%|████▊     | 80/167 [02:32<02:47,  1.93s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  49%|████▊     | 81/167 [02:34<02:36,  1.82s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  49%|████▉     | 82/167 [02:35<02:33,  1.81s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  50%|████▉     | 83/167 [02:37<02:25,  1.73s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  50%|█████     | 84/167 [02:39<02:26,  1.76s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  51%|█████     | 85/167 [02:40<02:19,  1.71s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  51%|█████▏    | 86/167 [02:42<02:19,  1.72s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  52%|█████▏    | 87/167 [02:44<02:13,  1.67s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  53%|█████▎    | 88/167 [02:45<02:13,  1.69s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  53%|█████▎    | 89/167 [02:47<02:08,  1.64s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  54%|█████▍    | 90/167 [02:48<02:00,  1.57s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  54%|█████▍    | 91/167 [02:50<02:09,  1.71s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  55%|█████▌    | 92/167 [02:52<02:03,  1.65s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  56%|█████▌    | 93/167 [02:54<02:04,  1.68s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  56%|█████▋    | 94/167 [02:55<02:02,  1.67s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  57%|█████▋    | 95/167 [02:57<02:02,  1.70s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  57%|█████▋    | 96/167 [02:59<02:04,  1.75s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  58%|█████▊    | 97/167 [03:00<01:57,  1.69s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  59%|█████▊    | 98/167 [03:02<01:58,  1.72s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  59%|█████▉    | 99/167 [03:04<01:54,  1.68s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  60%|█████▉    | 100/167 [03:06<01:54,  1.71s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  60%|██████    | 101/167 [03:07<01:49,  1.66s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  61%|██████    | 102/167 [03:09<01:57,  1.81s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  62%|██████▏   | 103/167 [03:11<01:56,  1.83s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  62%|██████▏   | 104/167 [03:13<01:49,  1.74s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  63%|██████▎   | 105/167 [03:15<01:52,  1.82s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  63%|██████▎   | 106/167 [03:16<01:46,  1.75s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  64%|██████▍   | 107/167 [03:18<01:45,  1.76s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  65%|██████▍   | 108/167 [03:20<01:40,  1.70s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  65%|██████▌   | 109/167 [03:22<01:41,  1.74s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  66%|██████▌   | 110/167 [03:23<01:35,  1.68s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  66%|██████▋   | 111/167 [03:24<01:29,  1.59s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  67%|██████▋   | 112/167 [03:26<01:26,  1.57s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  68%|██████▊   | 113/167 [03:27<01:21,  1.51s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  68%|██████▊   | 114/167 [03:29<01:23,  1.58s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  69%|██████▉   | 115/167 [03:31<01:22,  1.58s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  69%|██████▉   | 116/167 [03:32<01:24,  1.66s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  70%|███████   | 117/167 [03:34<01:24,  1.70s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  71%|███████   | 118/167 [03:36<01:28,  1.80s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  71%|███████▏  | 119/167 [03:38<01:30,  1.88s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  72%|███████▏  | 120/167 [03:41<01:35,  2.03s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  72%|███████▏  | 121/167 [03:42<01:26,  1.89s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  73%|███████▎  | 122/167 [03:44<01:25,  1.90s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  74%|███████▎  | 123/167 [03:46<01:18,  1.79s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  74%|███████▍  | 124/167 [03:48<01:28,  2.05s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  75%|███████▍  | 125/167 [03:50<01:19,  1.90s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  75%|███████▌  | 126/167 [03:52<01:18,  1.92s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  76%|███████▌  | 127/167 [03:53<01:12,  1.80s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  77%|███████▋  | 128/167 [03:55<01:06,  1.72s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  77%|███████▋  | 129/167 [03:57<01:09,  1.83s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  78%|███████▊  | 130/167 [03:59<01:12,  1.96s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  78%|███████▊  | 131/167 [04:01<01:05,  1.83s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  79%|███████▉  | 132/167 [04:03<01:03,  1.83s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  80%|███████▉  | 133/167 [04:04<00:58,  1.73s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# ...
#   chunk = pd.read_sql(query, con=conn)
#  77%|███████▋  | 149/193 [04:41<01:27,  2.00s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  78%|███████▊  | 150/193 [04:43<01:22,  1.91s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  78%|███████▊  | 151/193 [04:45<01:21,  1.95s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  79%|███████▉  | 152/193 [04:46<01:15,  1.84s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  79%|███████▉  | 153/193 [04:48<01:13,  1.83s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  80%|███████▉  | 154/193 [04:50<01:07,  1.74s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  80%|████████  | 155/193 [04:51<01:07,  1.77s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  81%|████████  | 156/193 [04:53<01:02,  1.69s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  81%|████████▏ | 157/193 [04:55<01:04,  1.81s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  82%|████████▏ | 158/193 [04:57<01:00,  1.72s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  82%|████████▏ | 159/193 [04:58<00:59,  1.75s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  83%|████████▎ | 160/193 [05:00<00:55,  1.68s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  83%|████████▎ | 161/193 [05:02<00:55,  1.72s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  84%|████████▍ | 162/193 [05:03<00:51,  1.67s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  84%|████████▍ | 163/193 [05:05<00:52,  1.77s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  85%|████████▍ | 164/193 [05:07<00:49,  1.70s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  85%|████████▌ | 165/193 [05:10<00:57,  2.05s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  86%|████████▌ | 166/193 [05:12<00:58,  2.15s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  87%|████████▋ | 167/193 [05:14<00:50,  1.95s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  87%|████████▋ | 168/193 [05:15<00:47,  1.92s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  88%|████████▊ | 169/193 [05:17<00:44,  1.86s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  88%|████████▊ | 170/193 [05:18<00:39,  1.71s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  89%|████████▊ | 171/193 [05:20<00:38,  1.76s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  89%|████████▉ | 172/193 [05:22<00:35,  1.70s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  90%|████████▉ | 173/193 [05:24<00:38,  1.91s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  90%|█████████ | 174/193 [05:27<00:41,  2.16s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  91%|█████████ | 175/193 [05:29<00:39,  2.19s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  91%|█████████ | 176/193 [05:31<00:33,  1.99s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  92%|█████████▏| 177/193 [05:33<00:32,  2.04s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  92%|█████████▏| 178/193 [05:34<00:28,  1.88s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  93%|█████████▎| 179/193 [05:36<00:26,  1.87s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  93%|█████████▎| 180/193 [05:38<00:22,  1.76s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  94%|█████████▍| 181/193 [05:39<00:19,  1.66s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  94%|█████████▍| 182/193 [05:41<00:17,  1.57s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  95%|█████████▍| 183/193 [05:42<00:16,  1.65s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  95%|█████████▌| 184/193 [05:44<00:14,  1.63s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  96%|█████████▌| 185/193 [05:47<00:15,  1.94s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  96%|█████████▋| 186/193 [05:48<00:13,  1.88s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 187/193 [05:50<00:10,  1.79s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 188/193 [05:52<00:08,  1.78s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 189/193 [05:53<00:06,  1.70s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 190/193 [05:55<00:05,  1.76s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▉| 191/193 [05:57<00:03,  1.69s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▉| 192/193 [05:58<00:01,  1.72s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_13572\2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# 100%|██████████| 193/193 [06:00<00:00,  1.87s/it]

# %%
#csvv.drop_duplicates(subset=['adressebetegnelse','areal']).sort_values('areal').head(50)

# %%
csv = csv.drop_duplicates(subset=['adressebetegnelse','areal'])
df_besp1 = df_besp.merge(csv[['adressebetegnelse', 'areal', 'anvendelseskode', 'Anvendelse']], how='outer', left_on='Adresse', right_on='adressebetegnelse')

#df_besp1.head(20)

# %%
#df_besp1['areal'].sort_values().value_counts().head(50)

# %%
df_besp.to_csv('../Data/besp/'+kunde+'.csv', header=True, sep=',', index=False)
dff.to_csv('../Data/timeforbrug/'+kunde+'.csv', header=True, sep=',', index=False)

# %%
df_besp = df_besp1
df_besp.shape
df_bbr.shape
# Out:
# (1, 31)

# %%
#csv, df_bbr = BBR_api(df_besp)
# Out:
#   0%|          | 0/323 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   0%|          | 1/323 [00:00<01:22,  3.90it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 2/323 [00:00<01:20,  4.00it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 3/323 [00:00<01:18,  4.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 4/323 [00:00<01:17,  4.12it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 5/323 [00:01<01:16,  4.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 6/323 [00:01<01:15,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 7/323 [00:01<01:15,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 8/323 [00:01<01:14,  4.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 9/323 [00:02<01:14,  4.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 10/323 [00:02<01:14,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 11/323 [00:02<01:13,  4.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▎         | 12/323 [00:02<01:14,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 13/323 [00:03<01:13,  4.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 14/323 [00:03<01:13,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 15/323 [00:03<01:13,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 16/323 [00:03<01:12,  4.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▌         | 17/323 [00:04<01:12,  4.24it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 18/323 [00:04<01:12,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 19/323 [00:04<01:12,  4.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 20/323 [00:04<01:12,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 21/323 [00:05<01:12,  4.15it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 22/323 [00:05<01:12,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 23/323 [00:05<01:11,  4.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 24/323 [00:05<01:11,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 25/323 [00:05<01:10,  4.23it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 26/323 [00:06<01:10,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 27/323 [00:06<01:10,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▊         | 28/323 [00:06<01:10,  4.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 29/323 [00:06<01:10,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 30/323 [00:07<01:09,  4.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|▉         | 31/323 [00:07<01:10,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|▉         | 32/323 [00:07<01:09,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|█         | 33/323 [00:07<01:10,  4.12it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 34/323 [00:08<01:09,  4.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 35/323 [00:08<01:09,  4.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 36/323 [00:08<01:12,  3.96it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█▏        | 37/323 [00:08<01:13,  3.87it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 38/323 [00:09<01:32,  3.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 39/323 [00:09<01:34,  3.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 40/323 [00:10<01:26,  3.27it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 41/323 [00:10<01:21,  3.48it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 42/323 [00:10<01:16,  3.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 43/323 [00:10<01:13,  3.83it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▎        | 44/323 [00:10<01:10,  3.95it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▍        | 45/323 [00:11<01:08,  4.03it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▍        | 46/323 [00:11<01:08,  4.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▍        | 47/323 [00:11<01:06,  4.12it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▍        | 48/323 [00:11<01:06,  4.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▌        | 49/323 [00:12<01:05,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▌        | 50/323 [00:12<01:07,  4.07it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▌        | 51/323 [00:12<01:06,  4.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▌        | 52/323 [00:12<01:07,  4.00it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▋        | 53/323 [00:13<01:06,  4.07it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 54/323 [00:13<01:06,  4.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 55/323 [00:13<01:06,  4.04it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 56/323 [00:13<01:09,  3.84it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 57/323 [00:14<01:12,  3.64it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 58/323 [00:14<01:12,  3.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 59/323 [00:14<01:13,  3.58it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▊        | 60/323 [00:15<01:12,  3.64it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▉        | 61/323 [00:15<01:11,  3.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▉        | 62/323 [00:15<01:12,  3.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|█▉        | 63/323 [00:16<01:25,  3.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|█▉        | 64/323 [00:16<01:21,  3.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|██        | 65/323 [00:16<01:19,  3.24it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|██        | 66/323 [00:16<01:15,  3.40it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██        | 67/323 [00:17<01:22,  3.10it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██        | 68/323 [00:17<01:15,  3.36it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██▏       | 69/323 [00:17<01:14,  3.43it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 70/323 [00:18<01:10,  3.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 71/323 [00:18<01:08,  3.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 72/323 [00:18<01:08,  3.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 73/323 [00:18<01:07,  3.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 74/323 [00:19<01:05,  3.81it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 75/323 [00:19<01:04,  3.82it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▎       | 76/323 [00:19<01:03,  3.86it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▍       | 77/323 [00:19<01:04,  3.84it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▍       | 78/323 [00:20<01:01,  3.95it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▍       | 79/323 [00:20<01:02,  3.90it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▍       | 80/323 [00:20<01:01,  3.95it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▌       | 81/323 [00:20<01:02,  3.88it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▌       | 82/323 [00:21<01:02,  3.85it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▌       | 83/323 [00:21<01:03,  3.80it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▌       | 84/323 [00:21<01:02,  3.83it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▋       | 85/323 [00:21<01:05,  3.63it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 86/323 [00:22<01:02,  3.77it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 87/323 [00:22<01:14,  3.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 88/323 [00:22<01:12,  3.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 89/323 [00:23<01:38,  2.37it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 90/323 [00:23<01:27,  2.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 91/323 [00:24<01:45,  2.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 92/323 [00:24<01:37,  2.38it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▉       | 93/323 [00:25<01:33,  2.46it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▉       | 94/323 [00:25<01:25,  2.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▉       | 95/323 [00:25<01:27,  2.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|██▉       | 96/323 [00:26<01:18,  2.88it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|███       | 97/323 [00:26<01:17,  2.91it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|███       | 98/323 [00:26<01:11,  3.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███       | 99/323 [00:27<01:08,  3.29it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███       | 100/323 [00:27<01:06,  3.36it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███▏      | 101/323 [00:27<01:04,  3.42it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 102/323 [00:27<01:01,  3.58it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 103/323 [00:28<01:00,  3.62it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 104/323 [00:28<00:58,  3.77it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 105/323 [00:28<00:57,  3.78it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 106/323 [00:28<00:56,  3.85it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 107/323 [00:29<00:58,  3.68it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 108/323 [00:29<00:56,  3.81it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▎      | 109/323 [00:29<00:56,  3.81it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▍      | 110/323 [00:29<00:54,  3.88it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▍      | 111/323 [00:30<00:56,  3.76it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▍      | 112/323 [00:30<00:54,  3.84it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▍      | 113/323 [00:30<00:54,  3.85it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▌      | 114/323 [00:31<00:52,  3.98it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 115/323 [00:31<00:51,  4.00it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 116/323 [00:31<00:50,  4.07it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 117/323 [00:31<00:51,  4.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 118/323 [00:31<00:51,  4.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 119/323 [00:32<00:51,  4.00it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 120/323 [00:32<00:49,  4.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 121/323 [00:32<00:49,  4.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 122/323 [00:32<00:48,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 123/323 [00:33<00:47,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 124/323 [00:33<00:48,  4.10it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▊      | 125/323 [00:33<00:49,  4.03it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▉      | 126/323 [00:33<00:48,  4.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▉      | 127/323 [00:34<00:47,  4.09it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|███▉      | 128/323 [00:34<00:47,  4.12it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|███▉      | 129/323 [00:34<00:46,  4.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|████      | 130/323 [00:34<00:46,  4.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████      | 131/323 [00:35<00:45,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████      | 132/323 [00:35<00:45,  4.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████      | 133/323 [00:35<00:44,  4.23it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████▏     | 134/323 [00:35<00:44,  4.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  86%|████████▌ | 351/409 [01:04<00:13,  4.28it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  86%|████████▌ | 352/409 [01:04<00:12,  4.71it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  86%|████████▋ | 353/409 [01:04<00:11,  4.82it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  87%|████████▋ | 357/409 [01:05<00:09,  5.63it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  88%|████████▊ | 359/409 [01:05<00:08,  5.63it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  88%|████████▊ | 360/409 [01:05<00:08,  5.76it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  88%|████████▊ | 361/409 [01:06<00:08,  5.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  89%|████████▊ | 362/409 [01:06<00:08,  5.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  89%|████████▉ | 363/409 [01:06<00:11,  4.04it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  89%|████████▉ | 364/409 [01:06<00:10,  4.45it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  89%|████████▉ | 365/409 [01:06<00:09,  4.71it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  90%|█████████ | 369/409 [01:08<00:09,  4.07it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  91%|█████████ | 371/409 [01:08<00:07,  4.89it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  91%|█████████ | 372/409 [01:08<00:07,  5.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  91%|█████████ | 373/409 [01:08<00:06,  5.48it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  91%|█████████▏| 374/409 [01:09<00:06,  5.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  92%|█████████▏| 377/409 [01:09<00:05,  5.81it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  92%|█████████▏| 378/409 [01:09<00:05,  5.69it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  93%|█████████▎| 379/409 [01:09<00:05,  5.77it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  93%|█████████▎| 380/409 [01:10<00:05,  5.69it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  93%|█████████▎| 381/409 [01:10<00:04,  5.71it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  93%|█████████▎| 382/409 [01:10<00:04,  5.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  94%|█████████▎| 383/409 [01:10<00:04,  5.71it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  95%|█████████▌| 389/409 [01:11<00:03,  6.04it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  95%|█████████▌| 390/409 [01:11<00:03,  5.87it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  96%|█████████▌| 391/409 [01:12<00:03,  5.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  96%|█████████▌| 392/409 [01:12<00:02,  5.85it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  96%|█████████▌| 393/409 [01:12<00:03,  4.92it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  96%|█████████▋| 394/409 [01:12<00:02,  5.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  97%|█████████▋| 395/409 [01:12<00:02,  5.31it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  98%|█████████▊| 399/409 [01:13<00:01,  5.76it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  98%|█████████▊| 400/409 [01:13<00:01,  5.71it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  99%|█████████▉| 404/409 [01:14<00:00,  5.79it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  99%|█████████▉| 405/409 [01:14<00:00,  5.83it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  99%|█████████▉| 406/409 [01:14<00:00,  5.95it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
# 100%|█████████▉| 407/409 [01:14<00:00,  5.79it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
# 100%|█████████▉| 408/409 [01:15<00:00,  5.85it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
# 100%|██████████| 409/409 [01:15<00:00,  5.44it/s]

# %%
# Out:
#                                 Adresse    besparelse  årligt forbrug  \
# 0        Gl Rådhusvej 13, 2750 Ballerup      0.000000   259497.680000
# 1               Solvej 6, 2750 Ballerup  18492.430667    51209.426667
# 2           Torvevej 19, 2740 Skovlunde  14179.082667   124158.146667
# 3           Rugvænget 10, 2750 Ballerup   7584.772000   193634.653333
# 4         Lundebjerg 72, 2740 Skovlunde  73013.465778   277289.364444
# 5                Kratvej 14, 2760 Måløv  68501.380381   264983.692381
# 6            Ejbyvej 47, 2740 Skovlunde  99065.460000   274540.890000
# 7         Magleparken 10, 2750 Ballerup  45695.537333   214193.373333
# 8         Bybjergvej 25, 2740 Skovlunde      0.000000   147015.266667
# 9           Platanbuen 1, 2750 Ballerup  70168.985714   325484.175714
# 10            Skovvej 55, 2750 Ballerup  31783.916667   129042.636667
# 11          Agernhaven 4, 2750 Ballerup   5868.720000    42019.813333
# 12         Magleparken 5, 2750 Ballerup  23983.501905   102120.113333
# 13          Torvevej 35, 2740 Skovlunde  -1588.964000      787.540000
# 14           Ejbyvej 55, 2740 Skovlunde      0.000000     2138.506667
# 15          Ejbyvej 111, 2740 Skovlunde      0.000000      512.673571
# 16         Bybjergvej 3, 2740 Skovlunde      0.000000    42531.146667
# 17  Ballerup Idrætsby 32, 2750 Ballerup  80052.012182   830454.314182
# 18          Marbækvej 16, 2750 Ballerup  10604.345556    14077.830000
# 19    Harrestrupvej 128, 2740 Skovlunde   2216.924667     4952.566667
#
#          last       best       mean  \
# 0   29.492138  29.492138  37.487211
# 1    5.996885   3.668496   5.388264
# 2   14.161923  12.474740  16.429893
# 3   22.078744  21.292184  27.812575
# 4   31.918706  23.240565  30.417506
# 5   30.543035  22.471494  30.184120
# 6   31.649651  20.075193  40.069975
# 7   23.860665  19.119017  34.783029
# 8   16.671578  16.671578  19.138057
# 9   37.504087  28.226602  38.192975
# 10  14.447244  10.952597  15.784760
# 11   4.885732   4.118944   5.058690
# 12  12.061858   8.857226  18.455775
# 13   0.094900   0.271970   0.348622
# 14   0.245369   0.245369   0.232113
# 15   0.058706   0.058706   0.123809
# 16   4.992216   4.992216   6.929423
# 17  95.009366  85.954412  97.958061
# 18   1.622392   0.397127   1.161622
# 19   0.570249   0.312774   0.604824
#
#                                                  bkps         meter  \
# 0   [2445, 3720, 4720, 5285, 5955, 6855, 8510, 981...  5.713132e+17
# 1   [1045, 1870, 2520, 3245, 3695, 4550, 5255, 840...  5.713132e+17
# 2   [1195, 1700, 2370, 3355, 4360, 5090, 5930, 101...  5.713132e+17
# 3   [1275, 2200, 2745, 3765, 4205, 5185, 6045, 672...  5.713132e+17
# 4   [1305, 2205, 3180, 3745, 4370, 5290, 5885, 727...  5.713132e+17
# 5   [865, 1330, 2290, 3840, 4445, 5255, 6060, 7035...  5.713132e+17
# 6   [860, 2370, 3355, 4360, 5165, 5830, 6880, 7610...  5.713132e+17
# 7   [1370, 2200, 2740, 3285, 4190, 5095, 5930, 688...  5.713132e+17
# 8   [870, 4065, 5775, 7130, 7560, 8500, 9745, 1092...  5.713132e+17
# 9   [370, 865, 2205, 2595, 3740, 5260, 5880, 6800,...  5.713132e+17
# 10  [860, 1240, 2370, 4205, 5260, 6090, 6720, 7105...  5.713132e+17
# 11  [530, 2080, 3245, 5930, 6760, 7600, 8405, 9415...  5.713132e+17
# 12  [1520, 2505, 3670, 4755, 5600, 6340, 7010, 768...  5.713132e+17
# 13  [1695, 2910, 4480, 5820, 7385, 8210, 8685, 103...  5.713132e+17
# 14  [815, 1960, 2605, 4000, 5535, 6435, 7285, 8150...  5.713132e+17
# 15        [360, 1505, 2275, 3040, 5710, 10045, 11351]  5.713132e+17
# 16  [1100, 1795, 2825, 7410, 8470, 10445, 10990, 1...  5.713132e+17
# 17  [1365, 2515, 3310, 4110, 4935, 5720, 6415, 703...  5.713132e+17
# 18  [510, 1765, 2485, 3485, 4480, 6015, 6915, 8095...  5.713132e+17
# 19  [1045, 1615, 2440, 4620, 5305, 6255, 7615, 847...  5.713132e+17
#
#                                            bkps_value   total kwh           %  \
# 0   [46.28472801635992, 38.11173333333333, 32.3968...   426417.03    0.000000
# 1   [5.725779904306219, 5.805369696969698, 5.39855...    61162.18   36.111380
# 2   [17.83341422594142, 17.92940594059406, 17.3522...   186495.72   11.420179
# 3   [30.700768627450977, 32.41547027027027, 24.740...   315700.54    3.917053
# 4   [30.99321072796935, 33.47655555555556, 29.7150...   345269.11   26.331145
# 5   [34.435653179190744, 30.66698924731183, 33.145...   342619.95   25.851168
# 6   [45.21204651162791, 43.176741721854306, 38.106...   454834.29   36.084046
# 7   [42.122737226277366, 38.178590361445785, 30.53...   394822.16   21.333777
# 8   [19.878999999999998, 18.48045070422535, 19.419...   217236.09    0.000000
# 9   [37.02762162162162, 44.49725252525253, 40.1164...   433528.46   21.558340
# 10  [17.87822093023256, 14.453421052631578, 18.006...   179172.81   24.630554
# 11  [5.231471698113207, 5.206477419354838, 4.11894...    57421.19   13.966554
# 12  [27.037486842105267, 25.432558375634517, 13.23...   209491.50   23.485581
# 13  [0.33332743362831857, 0.37391769547325104, 0.3...     3957.21 -201.762958
# 14  [0.24201226993865033, 0.17185152838427947, 0.3...     2634.71    0.000000
# 15  [0.10816666666666666, 0.16695196506550217, 0.1...     1405.36    0.000000
# 16  [8.376909090909091, 8.194028776978417, 6.24959...    78655.88    0.000000
# 17  [109.40878388278388, 100.2967652173913, 92.627...  1111921.95    9.639544
# 18  [0.7954901960784314, 1.6285498007968129, 1.444...    13185.57   75.326564
# 19  [0.94822009569378, 0.8422105263157895, 0.67175...     6865.36   44.763146
#
#                       adressebetegnelse    areal anvendeleskode
# 0        Gl Rådhusvej 13, 2750 Ballerup   5975.0            532
# 1               Solvej 6, 2750 Ballerup      NaN            NaN
# 2           Torvevej 19, 2740 Skovlunde   6242.0            360
# 3           Rugvænget 10, 2750 Ballerup   7439.0            350
# 4         Lundebjerg 72, 2740 Skovlunde   8759.0            421
# 5                Kratvej 14, 2760 Måløv   8934.0            421
# 6            Ejbyvej 47, 2740 Skovlunde   9756.0            421
# 7         Magleparken 10, 2750 Ballerup   3676.0            590
# 8         Bybjergvej 25, 2740 Skovlunde   3108.0            442
# 9           Platanbuen 1, 2750 Ballerup  14733.0            421
# 10            Skovvej 55, 2750 Ballerup   2688.0            421
# 11          Agernhaven 4, 2750 Ballerup   1100.0            441
# 12         Magleparken 5, 2750 Ballerup      NaN            NaN
# 13          Torvevej 35, 2740 Skovlunde    221.0            531
# 14           Ejbyvej 55, 2740 Skovlunde     96.0            449
# 15          Ejbyvej 111, 2740 Skovlunde    148.0            590
# 16         Bybjergvej 3, 2740 Skovlunde      NaN            NaN
# 17  Ballerup Idrætsby 32, 2750 Ballerup      NaN            NaN
# 18          Marbækvej 16, 2750 Ballerup    167.0            590
# 19    Harrestrupvej 128, 2740 Skovlunde      NaN            NaN

# %%
#df_besp.head()

# %%
dfff = dff[dff['Adresse']=='Vandmanden 5, 9200 Aalborg SV'].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'bkps': 'sum'}).reset_index()

fig, ax = plt.subplots(figsize=(14,4)) 
ax.plot(dfff['from'], dfff['amount'], linewidth=0.3)
ax.plot(dfff['from'], dfff['bkps'])
ax.plot(dfff['from'][dfff['bkps']==dfff['bkps'].min()], dfff['bkps'][dfff['bkps']==dfff['bkps'].min()], linewidth=6)

# %%
dfff.head()

# %%
def sql_query(df):
    df_adr = df['Adresse']
    fejl = []
    dfs = []
    for rows in tqdm(range(df_adr.shape[0])):
        query = """
        SELECT id_lokalid, husnummer
        FROM dar.adresse
        WHERE adressebetegnelse = '{}' 
        """.format(df_adr.iloc[rows])
        chunk = pd.read_sql(query, con=conn) 
        if chunk.empty: fejl.append(df_adr.iloc[rows])
        dfs.append(chunk)
    df = pd.concat(dfs, ignore_index=True)
    #df['ValidTo_reports'] = pd.to_datetime(df['ValidTo_reports'])
    #df = df[df['ValidTo_reports'].dt.date >= date.today()]
    df = df.reset_index()
    fejl = pd.DataFrame(fejl, columns=['Adresse'])
    return df, fejl

# %%
SERVER = "vsqlmorb"
PORT = '1433' 
USER = "pwu-morb"
PASSWORD = "JGo9822YbQvlcLtx"
DATABASE = "databox_aftagerknude"

conn = pyodbc.connect('Driver={SQL Server};'
                    'Server=' + SERVER +';'
                    'Database='+ DATABASE +';'
                    'UID=' + USER +';'
                    'PWD=' + PASSWORD + ';')
cursor = conn.cursor()

df, fejl = sql_query(df_besp)
# Out:
#   0%|          | 0/323 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   0%|          | 1/323 [00:00<01:26,  3.70it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 2/323 [00:00<01:21,  3.96it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 3/323 [00:00<01:21,  3.94it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 4/323 [00:01<01:20,  3.97it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 5/323 [00:01<01:21,  3.92it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 6/323 [00:01<01:21,  3.91it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 7/323 [00:01<01:19,  3.96it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 8/323 [00:02<01:17,  4.04it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 9/323 [00:02<01:16,  4.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 10/323 [00:02<01:15,  4.15it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 11/323 [00:02<01:17,  4.03it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▎         | 12/323 [00:02<01:16,  4.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 13/323 [00:03<01:15,  4.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 14/323 [00:03<01:14,  4.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 15/323 [00:03<01:14,  4.15it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 16/323 [00:03<01:13,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▌         | 17/323 [00:04<01:13,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 18/323 [00:04<01:12,  4.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 19/323 [00:04<01:12,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 20/323 [00:04<01:12,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 21/323 [00:05<01:12,  4.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 22/323 [00:05<01:12,  4.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 23/323 [00:05<01:13,  4.10it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 24/323 [00:05<01:16,  3.91it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 25/323 [00:06<01:15,  3.93it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 26/323 [00:06<01:14,  3.97it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 27/323 [00:06<01:13,  4.02it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▊         | 28/323 [00:06<01:11,  4.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 29/323 [00:07<01:13,  4.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 30/323 [00:07<01:12,  4.03it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|▉         | 31/323 [00:07<01:13,  4.00it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|▉         | 32/323 [00:07<01:11,  4.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|█         | 33/323 [00:08<01:14,  3.89it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 34/323 [00:08<01:22,  3.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 35/323 [00:08<01:18,  3.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 36/323 [00:09<01:21,  3.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█▏        | 37/323 [00:09<01:18,  3.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 38/323 [00:09<01:23,  3.43it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 39/323 [00:09<01:21,  3.47it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 40/323 [00:10<01:18,  3.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 41/323 [00:10<01:20,  3.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 42/323 [00:10<01:17,  3.62it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 43/323 [00:11<01:19,  3.53it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▎        | 44/323 [00:11<01:21,  3.43it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▍        | 45/323 [00:11<01:21,  3.42it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▍        | 46/323 [00:11<01:24,  3.28it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▍        | 47/323 [00:12<01:23,  3.29it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▍        | 48/323 [00:12<01:24,  3.26it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▌        | 49/323 [00:12<01:18,  3.47it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▌        | 50/323 [00:13<01:15,  3.62it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▌        | 51/323 [00:13<01:15,  3.62it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▌        | 52/323 [00:13<01:13,  3.68it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▋        | 53/323 [00:13<01:12,  3.73it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 54/323 [00:14<01:09,  3.85it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 55/323 [00:14<01:08,  3.93it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 56/323 [00:14<01:06,  4.02it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 57/323 [00:14<01:05,  4.05it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 58/323 [00:15<01:04,  4.10it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 59/323 [00:15<01:04,  4.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▊        | 60/323 [00:15<01:03,  4.13it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▉        | 61/323 [00:15<01:03,  4.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▉        | 62/323 [00:16<01:02,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|█▉        | 63/323 [00:16<01:03,  4.10it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|█▉        | 64/323 [00:16<01:02,  4.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|██        | 65/323 [00:16<01:02,  4.15it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|██        | 66/323 [00:16<01:00,  4.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██        | 67/323 [00:17<01:01,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██        | 68/323 [00:17<00:59,  4.27it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██▏       | 69/323 [00:17<01:00,  4.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 70/323 [00:17<01:00,  4.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 71/323 [00:18<01:00,  4.15it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 72/323 [00:18<00:59,  4.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 73/323 [00:18<01:00,  4.12it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 74/323 [00:18<01:00,  4.09it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 75/323 [00:19<01:01,  4.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▎       | 76/323 [00:19<01:00,  4.09it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▍       | 77/323 [00:19<01:00,  4.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▍       | 78/323 [00:19<01:01,  4.00it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▍       | 79/323 [00:20<01:02,  3.92it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▍       | 80/323 [00:20<01:05,  3.69it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▌       | 81/323 [00:20<01:04,  3.76it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▌       | 82/323 [00:21<01:03,  3.79it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▌       | 83/323 [00:21<01:07,  3.55it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▌       | 84/323 [00:21<01:06,  3.59it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▋       | 85/323 [00:21<01:05,  3.64it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 86/323 [00:22<01:03,  3.70it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 87/323 [00:22<01:01,  3.83it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 88/323 [00:22<01:03,  3.68it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 89/323 [00:22<01:01,  3.82it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 90/323 [00:23<00:59,  3.93it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 91/323 [00:23<01:00,  3.84it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 92/323 [00:23<00:58,  3.95it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▉       | 93/323 [00:23<00:57,  4.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▉       | 94/323 [00:24<00:56,  4.04it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▉       | 95/323 [00:24<00:57,  3.96it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|██▉       | 96/323 [00:24<00:56,  4.03it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|███       | 97/323 [00:24<00:57,  3.95it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|███       | 98/323 [00:25<00:57,  3.88it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███       | 99/323 [00:25<00:56,  3.94it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███       | 100/323 [00:25<00:55,  4.04it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███▏      | 101/323 [00:25<00:54,  4.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 102/323 [00:26<00:53,  4.12it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 103/323 [00:26<00:53,  4.15it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 104/323 [00:26<00:52,  4.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 105/323 [00:26<00:52,  4.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 106/323 [00:27<00:51,  4.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 107/323 [00:27<00:51,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 108/323 [00:27<00:50,  4.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▎      | 109/323 [00:27<00:50,  4.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▍      | 110/323 [00:28<00:49,  4.27it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▍      | 111/323 [00:28<00:49,  4.25it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▍      | 112/323 [00:28<00:49,  4.28it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▍      | 113/323 [00:28<00:52,  4.02it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▌      | 114/323 [00:29<00:51,  4.05it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 115/323 [00:29<00:51,  4.02it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 116/323 [00:29<00:51,  4.05it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 117/323 [00:29<00:52,  3.96it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 118/323 [00:30<00:55,  3.70it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 119/323 [00:30<00:55,  3.70it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 120/323 [00:30<00:54,  3.75it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 121/323 [00:30<00:53,  3.75it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 122/323 [00:31<00:52,  3.81it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 123/323 [00:31<00:52,  3.80it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 124/323 [00:31<00:50,  3.91it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▊      | 125/323 [00:31<00:50,  3.88it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▉      | 126/323 [00:32<00:51,  3.84it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▉      | 127/323 [00:32<00:51,  3.78it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|███▉      | 128/323 [00:32<00:50,  3.88it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|███▉      | 129/323 [00:32<00:50,  3.84it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|████      | 130/323 [00:33<00:49,  3.89it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████      | 131/323 [00:33<00:50,  3.77it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████      | 132/323 [00:33<00:49,  3.86it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████      | 133/323 [00:33<00:48,  3.95it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████▏     | 134/323 [00:34<00:48,  3.92it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# ...
#   chunk = pd.read_sql(query, con=conn)
#  86%|████████▋ | 279/323 [01:14<00:14,  3.04it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  87%|████████▋ | 280/323 [01:14<00:13,  3.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  87%|████████▋ | 281/323 [01:14<00:13,  3.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  87%|████████▋ | 282/323 [01:15<00:12,  3.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  88%|████████▊ | 283/323 [01:15<00:12,  3.29it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  88%|████████▊ | 284/323 [01:15<00:11,  3.49it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  88%|████████▊ | 285/323 [01:16<00:11,  3.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  89%|████████▊ | 286/323 [01:16<00:10,  3.41it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  89%|████████▉ | 287/323 [01:16<00:10,  3.51it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  89%|████████▉ | 288/323 [01:16<00:09,  3.63it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  89%|████████▉ | 289/323 [01:17<00:09,  3.76it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  90%|████████▉ | 290/323 [01:17<00:08,  3.80it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  90%|█████████ | 291/323 [01:17<00:08,  3.80it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  90%|█████████ | 292/323 [01:18<00:08,  3.71it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  91%|█████████ | 293/323 [01:18<00:08,  3.35it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  91%|█████████ | 294/323 [01:18<00:08,  3.46it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  91%|█████████▏| 295/323 [01:18<00:07,  3.68it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  92%|█████████▏| 296/323 [01:19<00:07,  3.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  92%|█████████▏| 297/323 [01:19<00:07,  3.58it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  92%|█████████▏| 298/323 [01:19<00:07,  3.51it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  93%|█████████▎| 299/323 [01:20<00:06,  3.49it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  93%|█████████▎| 300/323 [01:20<00:06,  3.61it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  93%|█████████▎| 301/323 [01:20<00:05,  3.76it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  93%|█████████▎| 302/323 [01:20<00:05,  3.90it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  94%|█████████▍| 303/323 [01:21<00:05,  3.95it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  94%|█████████▍| 304/323 [01:21<00:04,  3.98it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  94%|█████████▍| 305/323 [01:21<00:04,  4.04it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  95%|█████████▍| 306/323 [01:21<00:04,  4.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  95%|█████████▌| 307/323 [01:21<00:03,  4.12it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  95%|█████████▌| 308/323 [01:22<00:03,  4.02it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  96%|█████████▌| 309/323 [01:22<00:03,  3.92it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  96%|█████████▌| 310/323 [01:22<00:03,  3.79it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  96%|█████████▋| 311/323 [01:23<00:03,  3.36it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 312/323 [01:23<00:03,  3.33it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 313/323 [01:23<00:03,  3.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 314/323 [01:24<00:02,  3.26it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 315/323 [01:24<00:02,  3.36it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 316/323 [01:24<00:02,  3.50it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 317/323 [01:24<00:01,  3.44it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 318/323 [01:25<00:01,  3.48it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▉| 319/323 [01:25<00:01,  3.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▉| 320/323 [01:25<00:00,  3.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▉| 321/323 [01:25<00:00,  3.85it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# 100%|█████████▉| 322/323 [01:26<00:00,  3.89it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# 100%|██████████| 323/323 [01:26<00:00,  3.74it/s]

# %%
df.head()
# Out:
#    index                            id_lokalid  \
# 0      0  0a3f50a2-facc-32b8-e044-0003ba298018
# 1      1  2d5f65ce-fb97-4d79-ad1f-7e53cac22667
# 2      2  0a3f50a3-3408-32b8-e044-0003ba298018
# 3      3  0a3f50a3-1359-32b8-e044-0003ba298018
# 4      4  2e350495-4b1f-45b2-9bd0-acf015bd039e
#
#                               husnummer
# 0  0a3f507b-67d8-32b8-e044-0003ba298018
# 1  0a3f507b-7635-32b8-e044-0003ba298018
# 2  0a3f507b-88f9-32b8-e044-0003ba298018
# 3  0a3f507b-739d-32b8-e044-0003ba298018
# 4  0a3f507b-8412-32b8-e044-0003ba298018

# %%
fejl.shape
# Out:
# (25, 1)

# %%
csv, df = BBR_api(df_besp)
# Out:
#   0%|          | 0/323 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   0%|          | 1/323 [00:00<01:28,  3.65it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 2/323 [00:00<01:46,  3.02it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 3/323 [00:00<01:34,  3.38it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 4/323 [00:01<01:40,  3.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 5/323 [00:01<01:33,  3.42it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 6/323 [00:01<01:42,  3.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 7/323 [00:02<01:35,  3.32it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 8/323 [00:02<01:31,  3.46it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 9/323 [00:02<01:28,  3.57it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 10/323 [00:02<01:26,  3.62it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 11/323 [00:03<01:23,  3.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▎         | 12/323 [00:03<01:23,  3.73it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 13/323 [00:03<01:21,  3.81it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 14/323 [00:03<01:23,  3.71it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 15/323 [00:04<01:22,  3.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 16/323 [00:04<01:24,  3.65it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▌         | 17/323 [00:04<01:20,  3.78it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 18/323 [00:05<01:23,  3.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 19/323 [00:05<01:21,  3.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 20/323 [00:05<01:27,  3.47it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 21/323 [00:05<01:26,  3.49it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 22/323 [00:06<01:28,  3.40it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 23/323 [00:06<01:27,  3.43it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 24/323 [00:06<01:37,  3.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 25/323 [00:07<01:37,  3.05it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 26/323 [00:07<01:32,  3.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 27/323 [00:07<01:38,  3.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▊         | 28/323 [00:08<01:50,  2.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 29/323 [00:08<01:57,  2.51it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 30/323 [00:09<01:51,  2.64it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|▉         | 31/323 [00:09<01:40,  2.89it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|▉         | 32/323 [00:09<01:44,  2.78it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|█         | 33/323 [00:10<01:38,  2.94it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 34/323 [00:10<01:32,  3.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 35/323 [00:10<01:35,  3.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 36/323 [00:11<01:36,  2.99it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█▏        | 37/323 [00:11<01:28,  3.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 38/323 [00:11<01:47,  2.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 39/323 [00:12<02:04,  2.28it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 40/323 [00:12<01:49,  2.58it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 41/323 [00:13<01:38,  2.85it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 42/323 [00:13<01:32,  3.05it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 43/323 [00:13<01:30,  3.10it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▎        | 44/323 [00:13<01:30,  3.07it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▍        | 45/323 [00:14<01:24,  3.29it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▍        | 46/323 [00:14<01:21,  3.41it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▍        | 47/323 [00:14<01:17,  3.58it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▍        | 48/323 [00:14<01:14,  3.70it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▌        | 49/323 [00:15<01:14,  3.70it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▌        | 50/323 [00:15<01:12,  3.75it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▌        | 51/323 [00:15<01:11,  3.81it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▌        | 52/323 [00:16<01:11,  3.78it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▋        | 53/323 [00:16<01:11,  3.79it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 54/323 [00:16<01:10,  3.79it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 55/323 [00:16<01:09,  3.86it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 56/323 [00:17<01:18,  3.42it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 57/323 [00:17<01:14,  3.57it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 58/323 [00:17<01:12,  3.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 59/323 [00:17<01:10,  3.77it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▊        | 60/323 [00:18<01:08,  3.82it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▉        | 61/323 [00:18<01:08,  3.81it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  19%|█▉        | 62/323 [00:18<01:13,  3.56it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|█▉        | 63/323 [00:19<01:10,  3.68it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|█▉        | 64/323 [00:19<01:11,  3.64it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|██        | 65/323 [00:19<01:08,  3.76it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  20%|██        | 66/323 [00:19<01:07,  3.82it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██        | 67/323 [00:20<01:16,  3.35it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██        | 68/323 [00:20<01:12,  3.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  21%|██▏       | 69/323 [00:21<01:37,  2.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 70/323 [00:21<01:31,  2.76it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 71/323 [00:21<01:46,  2.36it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  22%|██▏       | 72/323 [00:22<01:35,  2.62it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 73/323 [00:22<01:29,  2.80it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 74/323 [00:22<01:25,  2.92it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  23%|██▎       | 75/323 [00:23<01:23,  2.97it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▎       | 76/323 [00:23<01:18,  3.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▍       | 77/323 [00:23<01:20,  3.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▍       | 78/323 [00:24<01:14,  3.27it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  24%|██▍       | 79/323 [00:24<01:14,  3.28it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▍       | 80/323 [00:24<01:10,  3.44it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▌       | 81/323 [00:24<01:08,  3.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  25%|██▌       | 82/323 [00:25<01:06,  3.63it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▌       | 83/323 [00:25<01:15,  3.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▌       | 84/323 [00:25<01:11,  3.35it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  26%|██▋       | 85/323 [00:26<01:09,  3.43it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 86/323 [00:26<01:07,  3.51it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 87/323 [00:26<01:12,  3.23it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  27%|██▋       | 88/323 [00:26<01:10,  3.33it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 89/323 [00:27<01:07,  3.45it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 90/323 [00:27<01:14,  3.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 91/323 [00:27<01:16,  3.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  28%|██▊       | 92/323 [00:28<01:10,  3.28it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▉       | 93/323 [00:28<01:07,  3.41it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▉       | 94/323 [00:28<01:05,  3.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  29%|██▉       | 95/323 [00:28<01:03,  3.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|██▉       | 96/323 [00:29<01:00,  3.73it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|███       | 97/323 [00:29<01:00,  3.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  30%|███       | 98/323 [00:29<01:05,  3.41it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███       | 99/323 [00:30<01:06,  3.38it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███       | 100/323 [00:30<01:05,  3.42it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  31%|███▏      | 101/323 [00:30<01:01,  3.59it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 102/323 [00:30<01:00,  3.68it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 103/323 [00:31<00:58,  3.73it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  32%|███▏      | 104/323 [00:31<00:58,  3.74it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 105/323 [00:31<00:59,  3.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 106/323 [00:32<00:58,  3.69it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 107/323 [00:32<00:57,  3.73it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  33%|███▎      | 108/323 [00:32<01:03,  3.40it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▎      | 109/323 [00:32<01:04,  3.29it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▍      | 110/323 [00:33<01:06,  3.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  34%|███▍      | 111/323 [00:33<01:07,  3.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▍      | 112/323 [00:33<01:04,  3.28it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▍      | 113/323 [00:34<01:02,  3.35it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  35%|███▌      | 114/323 [00:34<00:59,  3.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 115/323 [00:34<01:12,  2.87it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 116/323 [00:35<01:07,  3.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  36%|███▌      | 117/323 [00:35<01:05,  3.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 118/323 [00:35<01:01,  3.35it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 119/323 [00:36<00:59,  3.44it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 120/323 [00:36<01:10,  2.90it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  37%|███▋      | 121/323 [00:36<01:08,  2.93it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 122/323 [00:37<01:16,  2.63it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 123/323 [00:37<01:12,  2.77it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  38%|███▊      | 124/323 [00:37<01:11,  2.79it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▊      | 125/323 [00:38<01:09,  2.86it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▉      | 126/323 [00:38<01:09,  2.84it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  39%|███▉      | 127/323 [00:38<01:05,  2.97it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|███▉      | 128/323 [00:39<01:01,  3.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|███▉      | 129/323 [00:39<00:59,  3.27it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  40%|████      | 130/323 [00:39<00:56,  3.40it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████      | 131/323 [00:40<00:55,  3.49it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████      | 132/323 [00:40<00:53,  3.55it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████      | 133/323 [00:40<00:54,  3.47it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  41%|████▏     | 134/323 [00:40<00:54,  3.46it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  86%|████████▌ | 351/409 [01:25<00:12,  4.77it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  86%|████████▌ | 352/409 [01:25<00:12,  4.73it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  86%|████████▋ | 353/409 [01:26<00:11,  4.76it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  87%|████████▋ | 357/409 [01:27<00:13,  3.94it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  88%|████████▊ | 359/409 [01:28<00:19,  2.57it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  88%|████████▊ | 360/409 [01:28<00:16,  3.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  88%|████████▊ | 361/409 [01:28<00:14,  3.24it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  89%|████████▊ | 362/409 [01:28<00:12,  3.71it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  89%|████████▉ | 363/409 [01:28<00:10,  4.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  89%|████████▉ | 364/409 [01:29<00:10,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  89%|████████▉ | 365/409 [01:29<00:09,  4.53it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  90%|█████████ | 369/409 [01:30<00:11,  3.43it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  91%|█████████ | 371/409 [01:31<00:09,  4.02it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  91%|█████████ | 372/409 [01:31<00:10,  3.52it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  91%|█████████ | 373/409 [01:31<00:10,  3.58it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  91%|█████████▏| 374/409 [01:31<00:08,  3.94it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  92%|█████████▏| 377/409 [01:32<00:07,  4.39it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  92%|█████████▏| 378/409 [01:32<00:06,  4.44it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  93%|█████████▎| 379/409 [01:33<00:08,  3.54it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  93%|█████████▎| 380/409 [01:33<00:07,  4.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  93%|█████████▎| 381/409 [01:33<00:06,  4.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  93%|█████████▎| 382/409 [01:33<00:06,  4.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  94%|█████████▎| 383/409 [01:34<00:06,  4.32it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  95%|█████████▌| 389/409 [01:35<00:04,  4.68it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  95%|█████████▌| 390/409 [01:35<00:04,  4.54it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  96%|█████████▌| 391/409 [01:35<00:03,  4.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  96%|█████████▌| 392/409 [01:35<00:03,  4.84it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  96%|█████████▌| 393/409 [01:36<00:03,  4.58it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  96%|█████████▋| 394/409 [01:36<00:03,  4.82it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  97%|█████████▋| 395/409 [01:36<00:03,  4.65it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  98%|█████████▊| 399/409 [01:37<00:02,  4.50it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  98%|█████████▊| 400/409 [01:37<00:01,  4.68it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  99%|█████████▉| 404/409 [01:38<00:01,  4.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  99%|█████████▉| 405/409 [01:40<00:02,  1.63it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#  99%|█████████▉| 406/409 [01:40<00:01,  1.96it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
# 100%|█████████▉| 407/409 [01:40<00:00,  2.09it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
# 100%|█████████▉| 408/409 [01:40<00:00,  2.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
# 100%|██████████| 409/409 [01:41<00:00,  4.04it/s]

# %%
csv.head(50)
# Out:
#     index                            id_lokalid  \
# 0       0  0a3f50a2-facc-32b8-e044-0003ba298018
# 1       1  2d5f65ce-fb97-4d79-ad1f-7e53cac22667
# 2       2  0a3f50a3-3408-32b8-e044-0003ba298018
# 3       3  0a3f50a3-1359-32b8-e044-0003ba298018
# 4       4  2e350495-4b1f-45b2-9bd0-acf015bd039e
# 5       5  ee7ef6dc-0eba-4f74-bfe5-056f200c7030
# 6       6  e7d53961-ddd0-42ea-a302-9e425dc83f86
# 7       7  0a3f50a3-0b6e-32b8-e044-0003ba298018
# 8       8  fda1725c-1f12-4511-bba8-e8f32e0d7a9b
# 9       9  fda1725c-1f12-4511-bba8-e8f32e0d7a9b
# 10     10  fda1725c-1f12-4511-bba8-e8f32e0d7a9b
# 11     11  4d530d6c-4b06-48e4-8c61-6bbb30caee4d
# 12     12  4d530d6c-4b06-48e4-8c61-6bbb30caee4d
# 13     13  4d530d6c-4b06-48e4-8c61-6bbb30caee4d
# 14     14  3c9eb4c8-610c-41eb-8009-3abdd301f9a1
# 15     15  e04879cd-ae5c-4a24-aa5d-02a0e2ca1d6a
# 16     16  e04879cd-ae5c-4a24-aa5d-02a0e2ca1d6a
# 17     17  e04879cd-ae5c-4a24-aa5d-02a0e2ca1d6a
# 18     18  cd12f14a-87b7-49a8-9402-f38a366873fd
# 19     19  9000d6f4-e59e-4b67-a54b-d1b4bcb8c875
# 20     20  f02af57e-5b39-49f9-8428-05239be8e787
# 21     21  0a3f50a3-2168-32b8-e044-0003ba298018
# 22     22  3a6a17b1-d9c4-4669-8f3a-957dfdfc80f2
# 23     23  294e217c-40b5-4764-9a85-10fd101274b5
# 24     24  0a3f50a3-2db3-32b8-e044-0003ba298018
# 25     25  269e8419-4e89-4b50-9512-088aa2c1dcf8
# 26     26  0a3f50a3-117e-32b8-e044-0003ba298018
# 27     27  f09f4231-ae72-4d7e-a270-27f4dc056022
# 28     28  4915b734-85f9-4c68-a402-f574af925dc1
# 29     29  3c679f02-f0cb-426f-bbe3-07ad4935f7f7
# 30     30  343bef5d-25cd-4781-ab53-3fd39b44d4f1
# 31     31  aeccc1d2-fae8-43bd-97e2-2cd558bca411
# 32     32  0a3f50a3-1218-32b8-e044-0003ba298018
# 33     33  0a3f50a3-1250-32b8-e044-0003ba298018
# 34     34  7156d966-5f21-4c2d-9033-f18728a4c237
# 35     35  b9df494c-5a72-4695-91a2-1af4e02fb851
# 36     36  99acdd05-4e39-4da5-b9bb-d92194991939
# 37     37  122bc68b-9ec3-4218-8940-f547813ddb02
# 38     38  0a3f50a3-0582-32b8-e044-0003ba298018
# 39     39  ef8ae037-b50d-4230-a5d5-2e51d2efd70d
# 40     40  0a3f50a2-f92c-32b8-e044-0003ba298018
# 41     41  99dd6ea1-2e83-4c56-ba09-1601231472bd
# 42     42  b98ce75f-5391-49e6-b0e3-efa59e2915ff
# 43     43  930d4054-2bdb-437e-8f6b-f5dd1a817328
# 44     44  0a3f50a3-0423-32b8-e044-0003ba298018
# 45     45  36f8b64f-699f-40b0-8a3c-bdf0a089918f
# 46     46  0a3f50a3-0553-32b8-e044-0003ba298018
# 47     47  d417ed34-2ded-4850-a1e4-c862f05b9e85
# 48     48  3f276ca3-30d6-41ca-a152-c090538ce497
# 49     49  0a3f50a3-3a1c-32b8-e044-0003ba298018
#
#                                husnummer                    adressebetegnelse  \
# 0   0a3f507b-67d8-32b8-e044-0003ba298018       Gl Rådhusvej 13, 2750 Ballerup
# 1   0a3f507b-7635-32b8-e044-0003ba298018              Solvej 6, 2750 Ballerup
# 2   0a3f507b-88f9-32b8-e044-0003ba298018          Torvevej 19, 2740 Skovlunde
# 3   0a3f507b-739d-32b8-e044-0003ba298018          Rugvænget 10, 2750 Ballerup
# 4   0a3f507b-8412-32b8-e044-0003ba298018        Lundebjerg 72, 2740 Skovlunde
# 5   0a3f507b-8dff-32b8-e044-0003ba298018               Kratvej 14, 2760 Måløv
# 6   0a3f507b-7f7f-32b8-e044-0003ba298018           Ejbyvej 47, 2740 Skovlunde
# 7   0a3f507b-707c-32b8-e044-0003ba298018        Magleparken 10, 2750 Ballerup
# 8   0a3f507b-7e73-32b8-e044-0003ba298018        Bybjergvej 25, 2740 Skovlunde
# 9   0a3f507b-7e73-32b8-e044-0003ba298018        Bybjergvej 25, 2740 Skovlunde
# 10  0a3f507b-7e73-32b8-e044-0003ba298018        Bybjergvej 25, 2740 Skovlunde
# 11  0a3f507b-72d4-32b8-e044-0003ba298018          Platanbuen 1, 2750 Ballerup
# 12  0a3f507b-72d4-32b8-e044-0003ba298018          Platanbuen 1, 2750 Ballerup
# 13  0a3f507b-72d4-32b8-e044-0003ba298018          Platanbuen 1, 2750 Ballerup
# 14  0a3f507b-7586-32b8-e044-0003ba298018            Skovvej 55, 2750 Ballerup
# 15  0a3f507b-6131-32b8-e044-0003ba298018          Agernhaven 4, 2750 Ballerup
# 16  0a3f507b-6131-32b8-e044-0003ba298018          Agernhaven 4, 2750 Ballerup
# 17  0a3f507b-6131-32b8-e044-0003ba298018          Agernhaven 4, 2750 Ballerup
# 18  0a3f507b-7079-32b8-e044-0003ba298018         Magleparken 5, 2750 Ballerup
# 19  0a3f507b-8902-32b8-e044-0003ba298018          Torvevej 35, 2740 Skovlunde
# 20  0a3f507b-7f84-32b8-e044-0003ba298018           Ejbyvej 55, 2740 Skovlunde
# 21  0a3f507b-7f93-32b8-e044-0003ba298018          Ejbyvej 111, 2740 Skovlunde
# 22  ba3981f3-8b86-4ec3-881b-06c8aeed5430         Bybjergvej 3, 2740 Skovlunde
# 23  0a3f507b-7d9d-32b8-e044-0003ba298018  Ballerup Idrætsby 32, 2750 Ballerup
# 24  0a3f507b-8529-32b8-e044-0003ba298018          Marbækvej 16, 2750 Ballerup
# 25  0a3f507b-8071-32b8-e044-0003ba298018    Harrestrupvej 128, 2740 Skovlunde
# 26  0a3f507b-7269-32b8-e044-0003ba298018      Pederstrupvej 53, 2750 Ballerup
# 27  0a3f507b-7c15-32b8-e044-0003ba298018     Egebjergtoften 46, 2750 Ballerup
# 28  0a3f507b-7474-32b8-e044-0003ba298018      Sct. Jacobsvej 1, 2750 Ballerup
# 29  0a3f507b-933e-32b8-e044-0003ba298018         Østerhøjvej 1, 2750 Ballerup
# 30  0a3f507b-7251-32b8-e044-0003ba298018            Parkvej 9B, 2750 Ballerup
# 31  0a3f507b-67d9-32b8-e044-0003ba298018       Gl Rådhusvej 15, 2750 Ballerup
# 32  0a3f507b-72eb-32b8-e044-0003ba298018       Præstevænget 10, 2750 Ballerup
# 33  0a3f507b-72ed-32b8-e044-0003ba298018       Præstevænget 12, 2750 Ballerup
# 34  0a3f507b-72f0-32b8-e044-0003ba298018       Præstevænget 14, 2750 Ballerup
# 35  0a3f507b-63a6-32b8-e044-0003ba298018       Bispevangen 150, 2750 Ballerup
# 36  0a3f507b-6e48-32b8-e044-0003ba298018         Kornvænget 32, 2750 Ballerup
# 37  0a3f507b-73b5-32b8-e044-0003ba298018          Rugvænget 33, 2750 Ballerup
# 38  0a3f507b-6df5-32b8-e044-0003ba298018   Kirstinelundsvej 12, 2750 Ballerup
# 39  0a3f507b-6f14-32b8-e044-0003ba298018          Lautrupvej 6, 2750 Ballerup
# 40  0a3f507b-6608-32b8-e044-0003ba298018       Egebjerghuse 27, 2750 Ballerup
# 41  0a3f507b-6613-32b8-e044-0003ba298018       Egebjerghuse 39, 2750 Ballerup
# 42  0a3f507b-66af-32b8-e044-0003ba298018      Egebjergvang 233, 2750 Ballerup
# 43  0a3f507b-6c76-32b8-e044-0003ba298018          Håbets Vej 7, 2750 Ballerup
# 44  0a3f507b-6c77-32b8-e044-0003ba298018          Håbets Vej 9, 2750 Ballerup
# 45  0a3f507b-6dd7-32b8-e044-0003ba298018       Kildesvinget 16, 2750 Ballerup
# 46  0a3f507b-6dd9-32b8-e044-0003ba298018       Kildesvinget 36, 2750 Ballerup
# 47  0a3f507b-8df0-32b8-e044-0003ba298018                Kratvej 1, 2760 Måløv
# 48  0a3f507b-8dfa-32b8-e044-0003ba298018                Kratvej 9, 2760 Måløv
# 49  0a3f507b-8e14-32b8-e044-0003ba298018              Kratvej 30A, 2760 Måløv
#
#       areal anvendeleskode
# 0    5975.0            532
# 1       NaN            NaN
# 2    6242.0            360
# 3    7439.0            350
# 4    8759.0            421
# 5    8934.0            421
# 6    9756.0            421
# 7    3676.0            590
# 8    3108.0            442
# 9    3108.0            442
# 10   3108.0            442
# 11  14733.0            421
# 12  14733.0            421
# 13  14733.0            421
# 14   2688.0            421
# 15   1100.0            441
# 16   1100.0            441
# 17   1100.0            441
# 18      NaN            NaN
# 19    221.0            531
# 20     96.0            449
# 21    148.0            590
# 22      NaN            NaN
# 23      NaN            NaN
# 24    167.0            590
# 25      NaN            NaN
# 26    750.0            412
# 27      NaN            NaN
# 28      NaN            NaN
# 29    796.0            441
# 30     99.0            531
# 31      NaN            NaN
# 32    121.0            450
# 33    160.0            590
# 34    123.0            590
# 35    428.0            441
# 36      NaN            NaN
# 37   1467.0            441
# 38   1690.0            160
# 39   3576.0            429
# 40     96.0            530
# 41    448.0            441
# 42    474.0            441
# 43    551.0            590
# 44    878.0            219
# 45   5173.0            219
# 46    140.0            590
# 47    804.0            441
# 48   1060.0            590
# 49    159.0            350

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data = pd.read_csv('../MeteringPoints.csv', sep=';')
data2 = pd.read_csv('../Meterdata.csv', sep=';')
data = data.merge(data2)
data = data[['MålepunktsID', 'Juridisk_kontakt_By', 'Fra_dato', 'Til_dato', 'Mængde']]
data.columns = ['meter', 'Adresse', 'from', 'to', 'amount']
data['from'] = pd.to_datetime(data['from'])
#data['amount'] = pd.to_numeric(data['amount'])
data['day-moment'] = data['from'].dt.hour.map(get_day_moment)

data.head()
# Out:
#                 meter  Adresse                from                to  amount  \
# 0  571313123200330480  Mårslet 2019-04-19 00:00:00  19-04-2019 01:00    0.08
# 1  571313123200330480  Mårslet 2019-04-19 01:00:00  19-04-2019 02:00    0.07
# 2  571313123200330480  Mårslet 2019-04-19 02:00:00  19-04-2019 03:00    0.06
# 3  571313123200330480  Mårslet 2019-04-19 03:00:00  19-04-2019 04:00    0.07
# 4  571313123200330480  Mårslet 2019-04-19 04:00:00  19-04-2019 05:00    0.05
#
#   day-moment
# 0      night
# 1      night
# 2      night
# 3      night
# 4      night

# %%
df = data
df_besp, dff = besp()
dff['meter'] = pd.to_numeric(dff['meter'])
kunde = 'Privat_elforbrug_test'
df_besp.head()
dff = dff.iloc[889:]
dff.head()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\2830085382.py:80: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dff = df.groupby([df['from'].dt.day_name(locale='da_DK'), df['from'].dt.hour]).mean().reset_index(names=['day', 'hour'])
# C:\Users\misc\AppData\Local\Temp\ipykernel_26464\2830085382.py:80: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dff = df.groupby([df['from'].dt.day_name(locale='da_DK'), df['from'].dt.hour]).mean().reset_index(names=['day', 'hour'])
# C:\Users\misc\AppData\Local\Temp\ipykernel_26464\2830085382.py:169: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_besp = df_besp.append(ttt)
# C:\Users\misc\AppData\Local\Temp\ipykernel_26464\2830085382.py:170: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfff = dfff.append(dff)
# 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]
#                    from         meter  amount day-moment  Adresse     bkps
# 889 2019-04-24 00:00:00  5.713131e+17    0.08      night  Mårslet  0.96978
# 890 2019-04-24 01:00:00  5.713131e+17    0.07      night  Mårslet  0.96978
# 891 2019-04-24 02:00:00  5.713131e+17    0.07      night  Mårslet  0.96978
# 892 2019-04-24 03:00:00  5.713131e+17    0.07      night  Mårslet  0.96978
# 893 2019-04-24 04:00:00  5.713131e+17    0.10      night  Mårslet  0.96978
