# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests
import urllib.request as request
from urllib.parse import quote

import ruptures as rpt

from datetime import datetime
from datetime import timedelta
from tqdm import tqdm
import pyodbc 

pd.options.mode.chained_assignment = None

# %%
def get_token():
    refresh_token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....LQK0L0S3NRzL5oEOCr2CUIhc08Bul0NjQzkahB7JsOw'
    try:
        access_token
    except NameError:
        url = "https://api.eloverblik.dk/ThirdPartyApi" + '/api/Token'
        headers = {'Authorization': 'Bearer ' + refresh_token}
        token_response = requests.get(url, headers=headers, timeout=5)
        token_response.raise_for_status()
        token_json = token_response.json()
        access_token = token_json['result']
        timelog = datetime.now() - timedelta(days=2)
    else:
        time_between_insertion = datetime.now() - timelog
        if  time_between_insertion.days > 1:
            url = "https://api.eloverblik.dk/ThirdPartyApi" + '/api/Token'
            headers = {'Authorization': 'Bearer ' + refresh_token}
            token_response = requests.get(url, headers=headers, timeout=5)
            token_response.raise_for_status()
            token_json = token_response.json()
            access_token = token_json['result']
            
            timelog = datetime.now()
    return access_token

def getMeterPoints(Customer):
    ApiKey = "3bb0bb5c-392d-4daa-8b0e-6a675387d08b"
    url = "https://superhub.dk/api/nrgiraadgivning/v2/meteringPoints"
    url = url + "?" + "apikey=" + ApiKey + "&customerKey=" + quote(Customer)
    response = requests.get(url)
    df = pd.json_normalize(response.json()) 
    df['meteringPointId'] = pd.to_numeric(df['meteringPointId'])
    IDs = df['meteringPointId'].to_list()
    return df, IDs

def sql_query(df):
    SERVER = "vsqlmorb"
    PORT = '1433' 
    USER = "pwu-morb"
    PASSWORD = "JGo9822YbQvlcLtx"
    DATABASE = "databox_aftagerknude"

    conn = pyodbc.connect('Driver={SQL Server};'
                        'Server=' + SERVER +';'
                        'Database='+ DATABASE +';'
                        'UID=' + USER +';'
                        'PWD=' + PASSWORD + ';')
    
    df_adr = df['Adresse']
    fejl = []
    dfs = []
    for rows in tqdm(range(df_adr.shape[0])):
        query = """
        SELECT id_lokalid, husnummer, adressebetegnelse
        FROM dar.adresse
        WHERE adressebetegnelse = '{}' 
        """.format(df_adr.iloc[rows])
        chunk = pd.read_sql(query, con=conn) 
        if chunk.empty: fejl.append(df_adr.iloc[rows])
        dfs.append(chunk)
    df = pd.concat(dfs, ignore_index=True)
    #df['ValidTo_reports'] = pd.to_datetime(df['ValidTo_reports'])
    #df = df[df['ValidTo_reports'].dt.date >= date.today()]
    df = df.reset_index()
    fejl = pd.DataFrame(fejl, columns=['Adresse'])
    return df, fejl

def BBR_api1(df):
    SERVER = "vsqlmorb"
    PORT = '1433' 
    USER = "pwu-morb"
    PASSWORD = "JGo9822YbQvlcLtx"
    DATABASE = "databox_aftagerknude"

    conn = pyodbc.connect('Driver={SQL Server};'
                        'Server=' + SERVER +';'
                        'Database='+ DATABASE +';'
                        'UID=' + USER +';'
                        'PWD=' + PASSWORD + ';')
    
    #df, _ = sql_query(df)

    df['areal'] = np.NaN
    df['anvendelseskode'] = np.NaN
    fejl = []
    dfs = []

    for rows in tqdm(range(df.shape[0])):
        query = """
        SELECT byg038samletbygningsareal, byg021bygningensanvendelse, byg007bygningsnummer, byg041bebyggetareal
        FROM bbr.bygning
        WHERE (Husnummer = '{}') AND (registreringtil IS NULL) AND (virkningtil IS NULL) AND (status = 6)
        """.format(df.iloc[rows]['husnummer'])
        chunk = pd.read_sql(query, con=conn) 
        #print(df['adressebetegnelse'].iloc[rows])
        #print(chunk['byg038samletbygningsareal'].head())
        #if chunk.empty: fejl.append(df.iloc[rows])
        #dfs.append(chunk)
        if 'byg038samletbygningsareal' in chunk.columns:
            df['areal'].iloc[rows] = chunk['byg038samletbygningsareal'].dropna().unique().sum()
        
        if pd.to_numeric(chunk['byg041bebyggetareal']).dropna().unique().sum() <= 5:
            df['areal'].iloc[rows] = chunk['byg041bebyggetareal'].dropna().unique().sum()
            
        if 'byg021bygningensanvendelse' in chunk.columns:
            df.at[rows, 'anvendelseskode'] = chunk['byg021bygningensanvendelse'].unique()
    #df = pd.concat(dfs, ignore_index=True)
    #df = df.reset_index()
    return df

def BBR_api2(df):
    SERVER = "vsqlmorb"
    PORT = '1433' 
    USER = "pwu-morb"
    PASSWORD = "JGo9822YbQvlcLtx"
    DATABASE = "databox_aftagerknude"

    conn = pyodbc.connect('Driver={SQL Server};'
                        'Server=' + SERVER +';'
                        'Database='+ DATABASE +';'
                        'UID=' + USER +';'
                        'PWD=' + PASSWORD + ';')
    
    

    for rows in tqdm(df.index[df['areal'] == 0].tolist()):
        query = """
        SELECT enh026enhedenssamledeareal, enh020enhedensanvendelse
        FROM bbr.enhed
        WHERE (id_lokalid = '{}') AND (registreringtil IS NULL) AND (virkningtil IS NULL) AND (status = 6)
        """.format(df.iloc[rows]['id_lokalid'])
        chunk = pd.read_sql(query, con=conn) 
        #print(df['adressebetegnelse'].iloc[rows])
        #print(chunk['byg038samletbygningsareal'].head())
        #if chunk.empty: fejl.append(df.iloc[rows])
        #dfs.append(chunk)
        if 'enh026enhedenssamledeareal' in chunk.columns:
            df['areal'].iloc[rows] = chunk['enh026enhedenssamledeareal'].dropna().unique().sum()
        if 'enh020enhedensanvendelse' in chunk.columns:
            df.at[rows, 'anvendelseskode'] = chunk['enh020enhedensanvendelse'].unique()
    
    for rows in tqdm(df.index[df['areal'] == 0].tolist()):
        query = """
        SELECT enh026enhedenssamledeareal, enh020enhedensanvendelse
        FROM bbr.enhed
        WHERE (id_lokalid = '{}') AND (registreringtil IS NULL) AND (virkningtil IS NULL) AND (status = 6)
        """.format(df.iloc[rows]['husnummer'])
        chunk = pd.read_sql(query, con=conn) 
        #print(df['adressebetegnelse'].iloc[rows])
        #print(chunk['byg038samletbygningsareal'].head())
        #if chunk.empty: fejl.append(df.iloc[rows])
        #dfs.append(chunk)
        if 'enh026enhedenssamledeareal' in chunk.columns:
            df['areal'].iloc[rows] = chunk['enh026enhedenssamledeareal'].dropna().unique().sum()
        if 'enh020enhedensanvendelse' in chunk.columns:
            df.at[rows, 'anvendelseskode'] = chunk['enh020enhedensanvendelse'].unique()
    #df = pd.concat(dfs, ignore_index=True)
    #df = df.reset_index()
    return df

def BBR_api2(df):
    SERVER = "vsqlmorb"
    PORT = '1433'
    USER = "pwu-morb"
    PASSWORD = "JGo9822YbQvlcLtx"
    DATABASE = "databox_aftagerknude"

    conn = pyodbc.connect('Driver={SQL Server};'
                          'Server=' + SERVER + ';'
                          'Database=' + DATABASE + ';'
                          'UID=' + USER + ';'
                          'PWD=' + PASSWORD + ';')

    for rows in tqdm(range(len(df))):
        query = """
        SELECT enh026enhedenssamledeareal, enh020enhedensanvendelse
        FROM bbr.enhed
        WHERE (id_lokalid = '{}') AND (registreringtil IS NULL) AND (virkningtil IS NULL) AND (status = 6)
        """.format(df['id_lokalid'].iloc[rows])
        chunk = pd.read_sql(query, con=conn)
        if 'enh026enhedenssamledeareal' in chunk.columns:
            df.at[rows, 'areal'] = chunk['enh026enhedenssamledeareal'].dropna().sum()
        if 'enh020enhedensanvendelse' in chunk.columns:
            df.at[rows, 'anvendelseskode'] = chunk['enh020enhedensanvendelse'].unique()

    for rows in tqdm(range(len(df))):
        query = """
        SELECT enh026enhedenssamledeareal, enh020enhedensanvendelse
        FROM bbr.enhed
        WHERE (id_lokalid = '{}') AND (registreringtil IS NULL) AND (virkningtil IS NULL) AND (status = 6)
        """.format(df['husnummer'].iloc[rows])
        chunk = pd.read_sql(query, con=conn)
        if 'enh026enhedenssamledeareal' in chunk.columns:
            df.at[rows, 'areal'] = chunk['enh026enhedenssamledeareal'].dropna().sum()
        if 'enh020enhedensanvendelse' in chunk.columns:
            df.at[rows, 'anvendelseskode'] = chunk['enh020enhedensanvendelse'].unique()

    return df


# def BBR_api(df):

#     df, fejl = sql_query(df)

#     username = 'MikkelSchmidt2S4J8@dfdprod01.sys'
#     password = '910Mikkel14!'
#     username = 'BYCKJWQMOJ'

#     payload = ''
#     headers = { 'Accept': 'application/json',
#                 'Content-Type': 'application/json' }

#     csv = df
#     #print(csv)
#     csv['areal'] = np.NaN
#     csv['anvendeleskode'] = np.NaN
#     #print(csv)
    
#     for i in tqdm(range(len(csv))):
#         url = 'https://services.datafordeler.dk/BBR/BBRPublic/1/rest/enhed?username=' + username + '&password=' + password + '&Format=JSON&AdresseIdentificerer=' + str(csv['id_lokalid'].iloc[i])
#         response = requests.get(url, headers=headers)
#         if response.status_code != 200:
#                 response = requests.get(url, headers=headers)
#         if response.status_code == 200:
#             data = response.json()
#             #print(data)
#             df = pd.json_normalize(data,)
#             if 'enh026EnhedensSamledeAreal' in df.columns:
#                 csv['areal'].iloc[i] = df['enh026EnhedensSamledeAreal'].unique().sum()
#                 csv['anvendeleskode'].iloc[i] = df['enh020EnhedensAnvendelse'].iloc[0]

#         if csv['areal'].iloc[i] == np.NaN:
#             url = 'https://services.datafordeler.dk/BBR/BBRPublic/1/rest/bygning?username=' + username + '&password=' + password + '&Format=JSON&Husnummer=' + str(csv['husnummer'].iloc[i])
#             response = requests.get(url, headers=headers)
#             print('husnummer')
#             print(csv['adressebetegnelse'].iloc[i])
#             if response.status_code != 200:
#                     response = requests.get(url, headers=headers)
#             if response.status_code == 200:
#                 print('kode 200')
#                 data = response.json()
#                 #print(data)
#                 df = pd.json_normalize(data,)
#                 if 'byg038samletbygningsareal' in df.columns:
#                     csv['areal'].iloc[i] = df['byg038samletbygningsareal'].unique().sum()
#                     csv['anvendeleskode'].iloc[i] = df['byg021bygningensanvendelse'].iloc[0]
            
#     return csv, df

    #csv.to_csv('../Data/Master data/' + 'Furesø Kommune1' + '.csv', index=False, mode='w', header=True, encoding='UTF-8')
        #dff = df[df['id_lokalId'] == str(lokalid[0])]


def getMeterReadings(meteringPoints):
    ApiKey = "3bb0bb5c-392d-4daa-8b0e-6a675387d08b"
    From = '31122021'#(datetime.today() - timedelta(days = 1000)).strftime('%d%m%Y')
    To = datetime.today().strftime('%d%m%Y')
    df = pd.DataFrame()
    Fails = 0
    for meter in tqdm(meteringPoints):
        url = "https://superhub.dk/api/nrgiraadgivning/v2/meterreadings"
        url = url + "?" + "apikey=" + ApiKey + "&meteringpointId=" + str(meter) + "&from=" + From + "&to=" + To
        
        response = requests.get(url)
        if response.status_code != 200:
            Fails += 1
            continue
        jso = response.json()

        dff = pd.json_normalize(jso)
        
        if (dff.columns == 'meteringPoints.Production').any():
            df_meter = pd.json_normalize(jso['meteringPoints'], 'Production')
        elif (dff.columns == 'meteringPoints.Consumption').any():
            df_meter = pd.json_normalize(jso['meteringPoints'], 'Consumption') 
        else:
            print(dff.head())
            continue
        df_meter['meter'] = jso['meteringPointId']
        df_meter['Adresse'] = jso['streetName'] + ' ' + jso['buildingNumber'] + ', ' + jso['postcode'] + ' ' + jso['cityName']
        df = pd.concat([df, df_meter], ignore_index=True)
    df['from'] = pd.to_datetime(df['from'], utc=True)
    df['meter'] = pd.to_numeric(df['meter'])
    print('Amount of fails: ' + str(Fails))
    #print(url)
    return df

def csv_individual_meters_business(fromdate):
    access_token = get_token()
    meters = IDs
    df = pd.DataFrame(columns=['målerID', 'Mængde',  'from', 'hour'])
    url = "https://api.eloverblik.dk/ThirdPartyApi" + '/api/MeterData/GetTimeSeries/' + fromdate + '/' + '2023-06-13' + '/Hour'
    for meter in tqdm(meters):
        #print(meter)
        body = """{{"meteringPoints": {{
            "meteringPoint": ["{0}"]
        }}
        }}""".format(meter)
        headers = {'Authorization': 'Bearer ' + access_token,
            'Accept': 'application/json',
            'Content-Type': 'application/json' }

        response = requests.post(url, data=body, headers=headers)
        
        if response.status_code != 200:
            print('response!')
            print(response.status_code)
        if response.status_code == 503 or response.status_code == 429:
            print('sleep')
            time.sleep(60)
            response = requests.post(url, data=body, headers=headers)
            if response.status_code != 200:
                print(response.status_code)
        response.raise_for_status()  # raises exception when not a 2xx response
        
        data = response.json()
        
        if not data['result'][0]['MyEnergyData_MarketDocument']['TimeSeries']:
            print(str(meter) + " List is empty")
            continue

        df_meter = pd.json_normalize(
            data['result'][0]['MyEnergyData_MarketDocument']['TimeSeries'][0]['Period'],
            'Point',
            meta=[['timeInterval', 'start'],['timeInterval', 'end']],
            errors='ignore')
        df_meter['målerID'] = meter
        #df['Måleenhed'] = 'kWh'
        df_meter['From_date']= pd.to_datetime(df_meter['timeInterval.start']).dt.date
        df_meter['To_date']= pd.to_datetime(df_meter['timeInterval.end']).dt.date
        df_meter['Mængde'] = pd.to_numeric(df_meter['out_Quantity.quantity'])
        #df['LY Mængde']=df['Mængde'].shift(365*24)
        df_meter['hour'] = pd.to_numeric(df_meter['position'])
        df_meter['from'] = pd.to_datetime(df_meter.To_date) + pd.to_timedelta(df_meter.hour-1, unit='h')
        df_meter = df_meter[['målerID', 'Mængde',  'from', 'hour']]
        df = pd.concat([df, df_meter], ignore_index=True)
        #df.to_csv('../Data/Individual meters/' + 'Guldborgsund Kommune' + '.csv', index=False, encoding='UTF-8', mode='a')
        
    return df

def get_day_moment(hour) -> str: 
    if 6 <= hour <= 18:
        return 'day'
    return 'night'

def ugeprofil(df):
            dff = df.groupby([df['from'].dt.day_name(locale='da_DK'), df['from'].dt.hour]).mean(numeric_only=True).reset_index(names=['day', 'hour'])
            dff['day_'] = dff['day']
            dff['day_'].replace({
                    "Mandag": 0,
                    "Tirsdag": 1,
                    "Onsdag": 2,
                    "Torsdag": 3,
                    "Fredag": 4,
                    "Lørdag": 5,
                    "Søndag": 6},
                    inplace=True,)
            dff.sort_values(['day_', 'hour'], ascending=True, inplace=True)
            dff['x-axis'] = dff.apply(lambda row: row['day'] + ' kl. ' + str(row['hour']), axis=1)
            return dff

def rupt(tid, df):
    nbkps = 12

    test = df['amount']
    points=np.array(test)
    n= len(points)
    if nbkps == 1:
        nbkps = np.floor(np.round(n/365*4))
    #Changepoint detection with dynamic programming search method
    model = "l1"  
    algo = rpt.Window(width=24*30, model=model, min_size=3, jump=5).fit(points)
    my_bkps = algo.predict(n_bkps=nbkps)

    return my_bkps

def besp():
    df_besp = pd.DataFrame(columns=['Adresse', 'besparelse', 'årligt forbrug', 'last', 'best', 'mean', 'bkps'])
    dfff = pd.DataFrame()
    
    for adr in tqdm(df['Adresse'].unique()):
        dff = df[df['Adresse']==adr]
        #print(adr)
        #print(dff.shape)
        dff['day-moment'] = dff['from'].dt.hour.map(get_day_moment)
        dff = dff.groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first', 'Adresse': 'first'}).reset_index()
        my_bkps = rupt('day', dff)

        value_avg_day = np.zeros(len(dff['amount']))
        #stdd_avg_day  = np.zeros(len(dff['amount']))
        vvvv = np.zeros((len(my_bkps),2),)
        k=0
        j=0
        for i in my_bkps:
            value_avg_day[j:i] = np.mean(dff['amount'][j:i])
            #stdd_avg_day[j:i]  = np.std(dff['amount'][j:i])
            vvvv[k, 0] = np.mean(dff['amount'][j:i])
            vvvv[k, 1] = i
            k += 1
            j=i
        dff['bkps'] = value_avg_day
        #print(dff['bkps'])
        
        if dff['bkps'].iloc[-1] >= dff['bkps'].max():
            df_opti = dff[dff['bkps']==dff['bkps'].iloc[-1]].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
        else:
            df_opti = dff[dff['bkps']==dff['bkps'].min()].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
            k=1
            while df_opti['amount'].mean() <= 0.2:
                dff1 = dff[~(dff['bkps']==dff['bkps'].min())]
                df_opti = dff1[dff1['bkps']==dff1['bkps'].min()].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
                k += 1
                del dff1
                if (k == 10):
                    df_opti = dff[dff['bkps']==dff['bkps'].iloc[-1]].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
                    break
                
        df_norm = dff[dff['bkps']==dff['bkps'].iloc[-1]].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()

        uge = ugeprofil(df_opti)
        uge2 = ugeprofil(df_norm) 
        #print(my_bkps)

        ugg = uge[['day', 'hour', 'amount', 'x-axis']].merge(uge2[['day', 'hour', 'amount']], how='outer', on=['day', 'hour'], suffixes=('_opti', '_now'))
        ugg['besparelse_kwh'] = ugg['amount_now'] - ugg['amount_opti']
        ttt = pd.DataFrame(data={'Adresse': [adr], 
                                 'besparelse': [ugg['besparelse_kwh'].sum()*52], 
                                 'årligt forbrug': [ugg['amount_now'].sum()*52],
                                 'last': df_norm['amount'].mean(),
                                 'best': df_opti['amount'].mean(), 
                                 'mean': dff['amount'].mean(),
                                 'meter': dff['meter'].mean(),
                                 'bkps': 0,
                                 'bkps_value': 0,
                                 'total kwh': dff['amount'].sum()} )
        ttt[['bkps', 'bkps_value']] = ttt[['bkps', 'bkps_value']].astype('object')
        ttt.at[0,'bkps'] = my_bkps
        ttt.at[0,'bkps_value'] = vvvv[:,0]
        df_besp = pd.concat([df_besp,ttt])
        dfff = pd.concat([dfff, dff])

    df_besp = df_besp[df_besp['årligt forbrug'] != 0.0]
    df_besp['%'] = df_besp.apply(lambda row: row['besparelse']/row['årligt forbrug']*100, axis=1)
    return df_besp, dfff

# import holidays

# def besp():
#     df_besp = pd.DataFrame(columns=['Adresse', 'besparelse', 'årligt forbrug', 'last', 'best', 'mean', 'bkps'])
#     dfff = pd.DataFrame()

#     # Get Danish holidays for the relevant year
#     year = 2023
#     dk_holidays = holidays.Denmark(years=year)

#     for adr in tqdm(df['Adresse'].unique()):
#         dff = df[df['Adresse'] == adr]
#         dff['day-moment'] = dff['from'].dt.hour.map(get_day_moment)

#         # Add a column for the week of the year
#         dff['week'] = dff['from'].dt.isocalendar().week

#         # Define vacation weeks
#         vacation_weeks = [7, 8, 42, 51, 52, 1] + list(range(27, 33))

#         # Add a column indicating if the week is a vacation week
#         dff['is_vacation_week'] = dff['week'].isin(vacation_weeks)

#         # Consider holidays, July, and vacation weeks as holidays
#         dff['is_holiday'] = dff['from'].dt.date.isin(dk_holidays) | dff['is_vacation_week']

#         # Filter out data during holidays
#         dff = dff[~dff['is_holiday']]
#         dff = dff.drop(columns=['is_holiday', 'is_vacation_week', 'week'])


#         dff = dff.groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first', 'Adresse': 'first'}).reset_index()
#         my_bkps = rupt('day', dff)

#         value_avg_day = np.zeros(len(dff['amount']))
#         vvvv = np.zeros((len(my_bkps), 2))
#         k = 0
#         j = 0
#         for i in my_bkps:
#             value_avg_day[j:i] = np.mean(dff['amount'][j:i])
#             vvvv[k, 0] = np.mean(dff['amount'][j:i])
#             vvvv[k, 1] = i
#             k += 1
#             j = i
#         dff['bkps'] = value_avg_day

#         if dff['bkps'].iloc[-1] >= dff['bkps'].max():
#             df_opti = dff[dff['bkps'] == dff['bkps'].iloc[-1]].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
#         else:
#             df_opti = dff[dff['bkps'] == dff['bkps'].min()].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
#             k = 1
#             while df_opti['amount'].mean() <= 0.2:
#                 dff1 = dff[~(dff['bkps'] == dff['bkps'].min())]
#                 df_opti = dff1[dff1['bkps'] == dff1['bkps'].min()].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
#                 k += 1
#                 del dff1
#                 if k == 10:
#                     df_opti = dff[dff['bkps'] == dff['bkps'].iloc[-1]].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()
#                     break

#         df_norm = dff[dff['bkps'] == dff['bkps'].iloc[-1]].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'day-moment': 'first'}).reset_index()

#         uge = ugeprofil(df_opti)
#         uge2 = ugeprofil(df_norm)
#         ugg = uge[['day', 'hour', 'amount', 'x-axis']].merge(uge2[['day', 'hour', 'amount']], how='outer', on=['day', 'hour'], suffixes=('_opti', '_now'))
#         ugg['besparelse_kwh'] = ugg['amount_now'] - ugg['amount_opti']
#         ttt = pd.DataFrame(data={'Adresse': [adr], 
#                                  'besparelse': [ugg['besparelse_kwh'].sum() * 52], 
#                                  'årligt forbrug': [ugg['amount_now'].sum() * 52],
#                                  'last': df_norm['amount'].mean(),
#                                  'best': df_opti['amount'].mean(),
#                                  'mean': dff['amount'].mean(),
#                                  'meter': dff['meter'].mean(),
#                                  'bkps': 0,
#                                  'bkps_value': 0,
#                                  'total kwh': dff['amount'].sum()})
#         ttt[['bkps', 'bkps_value']] = ttt[['bkps', 'bkps_value']].astype('object')
#         ttt.at[0, 'bkps'] = my_bkps
#         ttt.at[0, 'bkps_value'] = vvvv[:, 0]
#         df_besp = pd.concat([df_besp, ttt])
#         dfff = pd.concat([dfff, dff])

#     df_besp = df_besp[df_besp['årligt forbrug'] != 0.0]
#     df_besp['%'] = df_besp.apply(lambda row: row['besparelse'] / row['årligt forbrug'] * 100, axis=1)
#     return df_besp, dfff

# %%
df_mi = csv_individual_meters_business('2021-12-31')
# Out:
# 100%|██████████| 4/4 [00:18<00:00,  4.69s/it]

# %%
df_mi = df_mi.rename(columns={'målerID': 'meter', 'Mængde': 'amount', 'end': 'from'})
df_mi.head()
# Out:
#                 meter  amount                from hour
# 0  571313123200029476    0.14 2021-12-31 00:00:00    1
# 1  571313123200029476    0.13 2021-12-31 01:00:00    2
# 2  571313123200029476    0.13 2021-12-31 02:00:00    3
# 3  571313123200029476    0.11 2021-12-31 03:00:00    4
# 4  571313123200029476    0.11 2021-12-31 04:00:00    5

# %%
df_mid = df_mi.merge(df, how='outer', left_on='meter', right_on='meteringPointId')
df_mid['Adresse'] = df_mid['streetName'] + ' ' + df_mid['buildingNumber'] + ', ' + df_mid['postcode'] + ' ' + df_mid['cityName']

# %%
df_mid.shape
# Out:
# (50756, 10)

# %%
df_mid.head()
# Out:
#                 meter  amount                from hour     meteringPointId  \
# 0  571313123200029476    0.14 2021-12-31 00:00:00    1  571313123200029476
# 1  571313123200029476    0.13 2021-12-31 01:00:00    2  571313123200029476
#       meteringPointId             streetName buildingNumber postcode  \
# 0  571313103202591010           Øster Kærvej             16     9700
# 1  571313115500000484             Lucernevej              2     9500
# 2  571313179101099698  Kokkedal Industripark              7     2980
# 3  571313155300086561             Vestergade             31     5800
# 4  571313155411589326               Roersvej             33     5000
#
#       cityName
# 0  Brønderslev
# 1        Hobro
# 2     Kokkedal
# 3       Nyborg
# 4     Odense C

# %%
df = getMeterReadings(IDs)
# Out:
#   0%|          | 0/142 [00:00<?, ?it/s]
# 100%|██████████| 142/142 [04:10<00:00,  1.77s/it]
# Amount of fails: 0

# %%
df = df_mid[['meter', 'amount', 'from', 'Adresse']]
df[df['Adresse']=='Øster Kærvej 16, 9700 Brønderslev'].head()
# Out:
# Empty DataFrame
# Columns: [meter, amount, from, Adresse]
# Index: []

# %%
#df.tail()

# %%
df['day-moment'] = df['from'].dt.hour.map(get_day_moment)

# %%
df_besp, dff = besp()
dff['meter'] = pd.to_numeric(dff['meter'])
df_besp.head()
# Out:
# 100%|██████████| 104/104 [00:52<00:00,  1.96it/s]
#                                   Adresse    besparelse  årligt forbrug  \
# 0       Øster Kærvej 16, 9700 Brønderslev  31356.771746   236273.229524
# 0                Lucernevej 2, 9500 Hobro    760.569333     7900.689333
# 0  Kokkedal Industripark 7, 2980 Kokkedal      0.000000   137718.290667
# 0              Vestergade 31, 5800 Nyborg  13025.913333   140619.440000
# 0              Roersvej 33, 5000 Odense C      0.000000   223435.217778
#
#         last       best       mean  \
# 0  26.669550  23.351145  29.595463
# 0   0.911450   0.771946   2.166660
# 0  15.812159  15.812159  22.151176
# 0  16.139808  14.652725  16.381912
# 0  25.607337  25.607337  26.540293
#
#                                                 bkps         meter  \
# 0  [695, 2490, 3040, 6455, 7295, 8420, 8975, 1032...  5.713131e+17
# 0  [710, 1720, 2475, 4095, 5950, 7465, 9615, 1102...  5.713131e+17
# 0  [2765, 4740, 5945, 6955, 7635, 8545, 9785, 109...  5.713132e+17
# 0  [1240, 1955, 4640, 5365, 5975, 7285, 8425, 113...  5.713132e+17
# 0                        [9800, 10980, 13515, 15047]  5.713132e+17
#
#                                           bkps_value  total kwh          %
# 0  [35.738834532374106, 34.93857938718663, 26.869...  445322.93  13.271403
# 0  [13.021661971830985, 10.616742574257426, 1.078...   32601.74   9.626620
# 0  [24.45274141048824, 20.20895696202532, 18.4270...  333308.75   0.000000
# 0  [17.134532258064517, 16.65606993006993, 16.268...  246498.63   9.263238
# 0  [26.239366326530615, 29.266483050847455, 26.99...  399351.79   0.000000

# %%
df_sql, _ = sql_query(df_besp)
# Out:
#   0%|          | 0/102 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 1/102 [00:01<01:47,  1.07s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 2/102 [00:01<01:00,  1.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 3/102 [00:01<00:49,  2.00it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         |
/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  66%|██████▌   | 67/102 [00:22<00:11,  2.93it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  67%|██████▋   | 68/102 [00:22<00:10,  3.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  68%|██████▊   | 69/102 [00:23<00:10,  3.03it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  69%|██████▊   | 70/102 [00:23<00:10,  3.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  70%|██████▉   | 71/102 [00:23<00:10,  3.00it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  71%|███████   | 72/102 [00:24<00:09,  3.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  72%|███████▏  | 73/102 [00:24<00:09,  3.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  73%|███████▎  | 74/102 [00:24<00:08,  3.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  74%|███████▎  | 75/102 [00:25<00:08,  3.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  75%|███████▍  | 76/102 [00:25<00:08,  3.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  75%|███████▌  | 77/102 [00:25<00:07,  3.23it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  76%|███████▋  | 78/102 [00:25<00:07,  3.37it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  77%|███████▋  | 79/102 [00:26<00:06,  3.50it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  78%|███████▊  | 80/102 [00:26<00:06,  3.15it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  79%|███████▉  | 81/102 [00:26<00:06,  3.26it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  80%|████████  | 82/102 [00:27<00:06,  3.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  81%|████████▏ | 83/102 [00:27<00:05,  3.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  82%|████████▏ | 84/102 [00:27<00:06,  2.95it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  83%|████████▎ | 85/102 [00:28<00:07,  2.36it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  84%|████████▍ | 86/102 [00:28<00:06,  2.58it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  85%|████████▌ | 87/102 [00:29<00:05,  2.74it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  86%|████████▋ | 88/102 [00:29<00:04,  2.93it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  87%|████████▋ | 89/102 [00:29<00:04,  2.97it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  88%|████████▊ | 90/102 [00:30<00:04,  2.78it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  89%|████████▉ | 91/102 [00:30<00:04,  2.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  90%|█████████ | 92/102 [00:30<00:03,  2.86it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  91%|█████████ | 93/102 [00:31<00:03,  2.99it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  92%|█████████▏| 94/102 [00:31<00:02,  3.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  93%|█████████▎| 95/102 [00:34<00:07,  1.10s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  94%|█████████▍| 96/102 [00:40<00:16,  2.67s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  95%|█████████▌| 97/102 [00:41<00:10,  2.15s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  96%|█████████▌| 98/102 [00:41<00:06,  1.59s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 99/102 [00:42<00:03,  1.33s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 100/102 [00:43<00:02,  1.33s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▉| 101/102 [00:45<00:01,  1.33s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:58: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# 100%|██████████| 102/102 [00:46<00:00,  2.18it/s]

# %%
df_sql.head()
# Out:
#    index                            id_lokalid  \
# 0      0  a71c03fc-41b1-4cd6-b36a-190472a658a0
# 1      1  a71c03fc-41b1-4cd6-b36a-190472a658a0
# 2      2  a71c03fc-41b1-4cd6-b36a-190472a658a0
# 3      3  c379b419-2277-4af0-8292-886fd0d44eba
# 4      4  ecf3b431-5e8f-40a6-8625-a40324b77222
#
#                               husnummer  \
# 0  0a3f5099-5e5b-32b8-e044-0003ba298018
# 1  0a3f5099-5e5b-32b8-e044-0003ba298018
# 2  0a3f5099-5e5b-32b8-e044-0003ba298018
# 3  0a3f509a-b8f7-32b8-e044-0003ba298018
# 4  5494fcb2-4685-49fb-a770-23827b183ec8
#
#                         adressebetegnelse
# 0       Øster Kærvej 16, 9700 Brønderslev
# 1       Øster Kærvej 16, 9700 Brønderslev
# 2       Øster Kærvej 16, 9700 Brønderslev
# 3                Lucernevej 2, 9500 Hobro
# 4  Kokkedal Industripark 7, 2980 Kokkedal

# %%
csv = BBR_api1(df_sql)
# Out:
#   0%|          | 0/148 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          |
/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  75%|███████▌  | 111/148 [00:12<00:05,  6.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  76%|███████▋  | 113/148 [00:12<00:04,  8.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  78%|███████▊  | 115/148 [00:12<00:04,  7.50it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  78%|███████▊  | 116/148 [00:13<00:06,  5.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  80%|███████▉  | 118/148 [00:13<00:04,  6.74it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  80%|████████  | 119/148 [00:13<00:04,  6.69it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  81%|████████  | 120/148 [00:14<00:07,  3.87it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  82%|████████▏ | 121/148 [00:14<00:06,  4.10it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  82%|████████▏ | 122/148 [00:14<00:07,  3.43it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  83%|████████▎ | 123/148 [00:14<00:05,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  84%|████████▍ | 125/148 [00:14<00:03,  6.33it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  86%|████████▌ | 127/148 [00:15<00:03,  5.29it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  86%|████████▋ | 128/148 [00:15<00:04,  4.57it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  88%|████████▊ | 130/148 [00:15<00:02,  6.47it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  89%|████████▉ | 132/148 [00:15<00:01,  8.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  91%|█████████ | 134/148 [00:16<00:01, 10.02it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  93%|█████████▎| 137/148 [00:16<00:00, 12.97it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  94%|█████████▍| 139/148 [00:16<00:00, 13.85it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  95%|█████████▌| 141/148 [00:16<00:00, 14.50it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 144/148 [00:16<00:00, 16.38it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▊| 146/148 [00:16<00:00, 17.15it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:94: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# 100%|██████████| 148/148 [00:16<00:00,  8.78it/s]

# %%
#csv.drop_duplicates(subset=['adressebetegnelse','areal']).sort_values('areal').head(60)

# %%
csv["Anvendelse"] = csv["anvendelseskode"].astype(str)
csv["Anvendelse"].replace(
    {
        "110": "Stuehus til landbrugsejendom",
        "120": "Fritliggende enfamiliehus",
        "121": "Sammenbygget enfamiliehus",
        "122": "Fritliggende enfamiliehus i tæt-lav bebyggelse",
        "130": "Række-, kæde-, eller dobbelthus",
        "131": "Række-, kæde- og klyngehus",
        "132": "Dobbelthus",
        "140": "Etagebolig-bygning, flerfamiliehus eller to-familiehus",
        "150": "Kollegium",
        "160": "Boligbygning til døgninstitution",
        "185": "Anneks i tilknytning til helårsbolig",
        "190": "Anden helårsbeboelse",
        "210": "Erhvervsmæssig produktion vedrørende landbrug, gartneri, råstofudvinding o. lign",
        "211": "Stald til svin",
        "212": "Stald til kvæg, får mv.",
        "213": "Stald til fjerkræ",
        "214": "Minkhal",
        "215": "Væksthus",
        "216": "Lade til foder, afgrøder mv.",
        "217": "Maskinhus, garage mv.",
        "218": "Lade til halm, hø mv.",
        "219": "Anden bygning til landbrug mv.",
        "220": "Erhvervsmæssig produktion vedrørende industri, håndværk m.v.",
        "221": "Industri med integreret produktionsapparat",
        "222": "Industri uden integreret produktionsapparat ",
        "223": "Værksted",
        "229": "Anden til produktion",
        "230": "El-, gas-, vand- eller varmeværk, forbrændingsanstalt m.v.",
        "231": "Energiproduktion",
        "232": "Forsyning- og energidistribution",
        "233": "Vandforsyning",
        "234": "Til håndtering af affald og spildevand",
        "239": "Anden til energiproduktion og -distribution",
        "290": "Anden til landbrug, industri etc.",
        "310": "Transport- og garageanlæg",
        "311": "Jernbane- og busdrift",
        "312": "Luftfart",
        "313": "Parkering- og transportanlæg",
        "314": "Parkering af flere end to køretøjer i tilknytning til boliger",
        "315": "Havneanlæg",
        "319": "Andet transportanlæg",
        "320": "Til kontor, handel, lager, herunder offentlig administration",
        "321": "Kontor",
        "322": "Detailhandel",
        "323": "Lager",
        "324": "Butikscenter",
        "325": "Tankstation",
        "329": "Anden til kontor, handel og lager",
        "330": "Til hotel, restaurant, vaskeri, frisør og anden servicevirksomhed",
        "331": "Hotel, kro eller konferencecenter med overnatning",
        "332": "Bed & breakfast mv.",
        "333": "Restaurant, café og konferencecenter uden overnatning",
        "334": "Privat servicevirksomhed som frisør, vaskeri, netcafé mv.",
        "339": "Anden til serviceerhverv",
        "390": "Anden til transport, handel etc",
        "410": "Biograf, teater, erhvervsmæssig udstilling, bibliotek, museum, kirke o. lign.",
        "411": "Biograf, teater, koncertsted mv.",
        "412": "Museum",
        "413": "Bibliotek",
        "414": "Kirke eller anden til trosudøvelse for statsanerkendte trossamfund",
        "415": "Forsamlingshus",
        "416": "Forlystelsespark",
        "419": "Anden til kulturelle formål",
        "420": "Undervisning og forskning (skole, gymnasium, forskningslabratorium o.lign.).",
        "421": "Grundskole",
        "422": "Universitet",
        "429": "Anden til undervisning og forskning",
        "430": "Hospital, sygehjem, fødeklinik o. lign.",
        "431": "Hospital og sygehus",
        "432": "Hospice, behandlingshjem mv.",
        "433": "Sundhedscenter, lægehus, fødeklinik mv.",
        "439": "Anden til sundhedsformål",
        "440": "Daginstitution",
        "441": "Daginstitution",
        "442": "Servicefunktion på døgninstitution",
        "443": "Kaserne",
        "444": "Fængsel, arresthus mv.",
        "449": "Anden til institutionsformål",
        "490": "Anden institution, herunder kaserne, fængsel o. lign.",
        "510": "Sommerhus",
        "520": "Feriekoloni, vandrehjem o.lign. bortset fra sommerhus",
        "521": "Feriecenter, center til campingplads mv.",
        "522": "Ferielejligheder til erhvervsmæssig udlejning",
        "523": "Ferielejligheder til eget brug",
        "529": "Anden til ferieformål",
        "530": "I forbindelse med idrætsudøvelse (klubhus, idrætshal, svømmehal o. lign.)",
        "531": "Klubhus i forbindelse med fritid og idræt",
        "532": "Svømmehal",
        "533": "Idrætshal",
        "534": "Tribune i forbindelse med stadion",
        "535": "Til træning og opstaldning af heste",
        "539": "Anden til idrætformål",
        "540": "Kolonihavehus",
        "585": "Anneks i tilknytning til fritids- og sommerhus",
        "590": "Anden til fritidsformål",
        "910": "Garage (med plads til et eller to køretøjer)",
        "920": "Carport",
        "930": "Udhus",
        "940": "Drivhus",
        "950": "Fritliggende overdækning",
        "960": "Fritliggende udestue",
        "970": "Tiloversbleven landbrugsbygning",
        "990": "Faldefærdig bygning",
        "999": "Ukendt bygning",
    },
    inplace=True,
)

# %%
csvv = BBR_api2(csv.drop_duplicates(subset=['adressebetegnelse','areal']))
# Out:
#   0%|          | 0/95 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 1/95 [00:01<02:43,  1.74s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 2/95 [00:03<02:47,  1.80s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 3/95 [00:05<02:50,  1.86s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 4/95 [00:07<02:52,  1.89s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▌         | 5/95 [00:09<02:52,  1.91s/it]C:\Users\misc\AppData\Local\Temp\ipykernel_50636\2196061834.py:180: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|
2196061834.py:192: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# 100%|██████████| 135/135 [04:37<00:00,  2.06s/it]

# %%
#csvv.drop_duplicates(subset=['adressebetegnelse','areal']).sort_values('areal').head(50)

# %%
csv = csv.drop_duplicates(subset=['adressebetegnelse','areal'])
df_besp1 = df_besp.merge(csv[['adressebetegnelse', 'areal', 'anvendelseskode', 'Anvendelse']], how='outer', left_on='Adresse', right_on='adressebetegnelse')

#df_besp1.head(20)

# %%
#df_besp1['areal'].sort_values().value_counts().head(50)

# %%
df_besp.to_csv('../Data/besp/'+kunde+'.csv', header=True, sep=',', index=False)
dff.to_csv('../Data/timeforbrug/'+kunde+'.csv', header=True, sep=',', index=False)

# %%
df_besp = df_besp1
df_besp.shape
df_bbr.shape
# Out:
# (1, 31)

# %%
#csv, df_bbr = BBR_api(df_besp)
# Out:
#   0%|          | 0/323 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   0%|          | 1/323 [00:00<01:22,  3.90it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 2/323 [00:00<01:20,  4.00it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 3/323 [00:00<01:18,  4.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 4/323 [00:00<01:17,  4.12it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 5/323 [00:01<01:16,  4.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 6/323 [00:01<01:15,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 7/323 [00:01<01:15,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 8/323 [00:01<01:14,  4.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 9/323 [00:02<01:14,  4.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 10/323 [00:02<01:14,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 11/323 [00:02<01:13,  4.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▎         | 12/323 [00:02<01:14,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 13/323 [00:03<01:13,  4.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 14/323 [00:03<01:13,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 15/323 [00:03<01:13,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 16/323 [00:03<01:12,  4.22it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▌         | 17/323 [00:04<01:12,  4.24it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 18/323 [00:04<01:12,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 19/323 [00:04<01:12,  4.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 20/323 [00:04<01:12,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 21/323 [00:05<01:12,  4.15it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 22/323 [00:05<01:12,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 23/323 [00:05<01:11,  4.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 24/323 [00:05<01:11,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 25/323 [00:05<01:10,  4.23it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 26/323 [00:06<01:10,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 27/323 [00:06<01:10,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▊         | 28/323 [00:06<01:10,  4.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 29/323 [00:06<01:10,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 30/323 [00:07<01:09,  4.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|▉         | 31/323 [00:07<01:10,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|▉         | 32/323 [00:07<01:09,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|█         | 33/323 [00:07<01:10,  4.12it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 34/323 [00:08<01:09,  4.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 35/323 [00:08<01:09,  4.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█         | 36/323 [00:08<01:12,  3.96it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  11%|█▏        | 37/323 [00:08<01:13,  3.87it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 38/323 [00:09<01:32,  3.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 39/323 [00:09<01:34,  3.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  12%|█▏        | 40/323 [00:10<01:26,  3.27it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 41/323 [00:10<01:21,  3.48it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 42/323 [00:10<01:16,  3.67it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  13%|█▎        | 43/323 [00:10<01:13,  3.83it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▎        | 44/323 [00:10<01:10,  3.95it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▍        | 45/323 [00:11<01:08,  4.03it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  14%|█▍        | 46/323 [00:11<01:08,  4.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▍        | 47/323 [00:11<01:06,  4.12it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▍        | 48/323 [00:11<01:06,  4.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▌        | 49/323 [00:12<01:05,  4.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  15%|█▌        | 50/323 [00:12<01:07,  4.07it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▌        | 51/323 [00:12<01:06,  4.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▌        | 52/323 [00:12<01:07,  4.00it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  16%|█▋        | 53/323 [00:13<01:06,  4.07it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 54/323 [00:13<01:06,  4.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 55/323 [00:13<01:06,  4.04it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  17%|█▋        | 56/323 [00:13<01:09,  3.84it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        | 57/323 [00:14<01:12,  3.64it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\3776361956.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  18%|█▊        |
# 15        [360, 1505, 2275, 3040, 5710, 10045, 11351]  5.713132e+17
# 16  [1100, 1795, 2825, 7410, 8470, 10445, 10990, 1...  5.713132e+17
# 17  [1365, 2515, 3310, 4110, 4935, 5720, 6415, 703...  5.713132e+17
# 18  [510, 1765, 2485, 3485, 4480, 6015, 6915, 8095...  5.713132e+17
# 19  [1045, 1615, 2440, 4620, 5305, 6255, 7615, 847...  5.713132e+17
#
#                                            bkps_value   total kwh           %  \
# 0   [46.28472801635992, 38.11173333333333, 32.3968...   426417.03    0.000000
# 1   [5.725779904306219, 5.805369696969698, 5.39855...    61162.18   36.111380
# 2   [17.83341422594142, 17.92940594059406, 17.3522...   186495.72   11.420179
# 3   [30.700768627450977, 32.41547027027027, 24.740...   315700.54    3.917053
# 4   [30.99321072796935, 33.47655555555556, 29.7150...   345269.11   26.331145
# 5   [34.435653179190744, 30.66698924731183, 33.145...   342619.95   25.851168
# 6   [45.21204651162791, 43.176741721854306, 38.106...   454834.29   36.084046
# 7   [42.122737226277366, 38.178590361445785, 30.53...   394822.16   21.333777
# 8   [19.878999999999998, 18.48045070422535, 19.419...   217236.09    0.000000
# 9   [37.02762162162162, 44.49725252525253, 40.1164...   433528.46   21.558340
# 10  [17.87822093023256, 14.453421052631578, 18.006...   179172.81   24.630554
# 11  [5.231471698113207, 5.206477419354838, 4.11894...    57421.19   13.966554
# 12  [27.037486842105267, 25.432558375634517, 13.23...   209491.50   23.485581
# 13  [0.33332743362831857, 0.37391769547325104, 0.3...     3957.21 -201.762958
# 14  [0.24201226993865033, 0.17185152838427947, 0.3...     2634.71    0.000000
# 15  [0.10816666666666666, 0.16695196506550217, 0.1...     1405.36    0.000000
# 16  [8.376909090909091, 8.194028776978417, 6.24959...    78655.88    0.000000
# 17  [109.40878388278388, 100.2967652173913, 92.627...  1111921.95    9.639544
# 18  [0.7954901960784314, 1.6285498007968129, 1.444...    13185.57   75.326564
# 19  [0.94822009569378, 0.8422105263157895, 0.67175...     6865.36   44.763146
#
#                       adressebetegnelse    areal anvendeleskode
# 0        Gl Rådhusvej 13, 2750 Ballerup   5975.0            532
# 1               Solvej 6, 2750 Ballerup      NaN            NaN
# 2           Torvevej 19, 2740 Skovlunde   6242.0            360
# 3           Rugvænget 10, 2750 Ballerup   7439.0            350
# 4         Lundebjerg 72, 2740 Skovlunde   8759.0            421
# 5                Kratvej 14, 2760 Måløv   8934.0            421
# 6            Ejbyvej 47, 2740 Skovlunde   9756.0            421
# 7         Magleparken 10, 2750 Ballerup   3676.0            590
# 8         Bybjergvej 25, 2740 Skovlunde   3108.0            442
# 9           Platanbuen 1, 2750 Ballerup  14733.0            421
# 10            Skovvej 55, 2750 Ballerup   2688.0            421
# 11          Agernhaven 4, 2750 Ballerup   1100.0            441
# 12         Magleparken 5, 2750 Ballerup      NaN            NaN
# 13          Torvevej 35, 2740 Skovlunde    221.0            531
# 14           Ejbyvej 55, 2740 Skovlunde     96.0            449
# 15          Ejbyvej 111, 2740 Skovlunde    148.0            590
# 16         Bybjergvej 3, 2740 Skovlunde      NaN            NaN
# 17  Ballerup Idrætsby 32, 2750 Ballerup      NaN            NaN
# 18          Marbækvej 16, 2750 Ballerup    167.0            590
# 19    Harrestrupvej 128, 2740 Skovlunde      NaN            NaN

# %%
#df_besp.head()

# %%
dfff = dff[dff['Adresse']=='Vandmanden 5, 9200 Aalborg SV'].groupby('from').agg({'meter': 'mean', 'amount': 'sum', 'bkps': 'sum'}).reset_index()

fig, ax = plt.subplots(figsize=(14,4)) 
ax.plot(dfff['from'], dfff['amount'], linewidth=0.3)
ax.plot(dfff['from'], dfff['bkps'])
ax.plot(dfff['from'][dfff['bkps']==dfff['bkps'].min()], dfff['bkps'][dfff['bkps']==dfff['bkps'].min()], linewidth=6)

# %%
dfff.head()

# %%
def sql_query(df):
    df_adr = df['Adresse']
    fejl = []
    dfs = []
    for rows in tqdm(range(df_adr.shape[0])):
        query = """
        SELECT id_lokalid, husnummer
        FROM dar.adresse
        WHERE adressebetegnelse = '{}' 
        """.format(df_adr.iloc[rows])
        chunk = pd.read_sql(query, con=conn) 
        if chunk.empty: fejl.append(df_adr.iloc[rows])
        dfs.append(chunk)
    df = pd.concat(dfs, ignore_index=True)
    #df['ValidTo_reports'] = pd.to_datetime(df['ValidTo_reports'])
    #df = df[df['ValidTo_reports'].dt.date >= date.today()]
    df = df.reset_index()
    fejl = pd.DataFrame(fejl, columns=['Adresse'])
    return df, fejl

# %%
SERVER = "vsqlmorb"
PORT = '1433' 
USER = "pwu-morb"
PASSWORD = "JGo9822YbQvlcLtx"
DATABASE = "databox_aftagerknude"

conn = pyodbc.connect('Driver={SQL Server};'
                    'Server=' + SERVER +';'
                    'Database='+ DATABASE +';'
                    'UID=' + USER +';'
                    'PWD=' + PASSWORD + ';')
cursor = conn.cursor()

df, fejl = sql_query(df_besp)
# Out:
#   0%|          | 0/323 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   0%|          | 1/323 [00:00<01:26,  3.70it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 2/323 [00:00<01:21,  3.96it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 3/323 [00:00<01:21,  3.94it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 4/323 [00:01<01:20,  3.97it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 5/323 [00:01<01:21,  3.92it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 6/323 [00:01<01:21,  3.91it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 7/323 [00:01<01:19,  3.96it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 8/323 [00:02<01:17,  4.04it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 9/323 [00:02<01:16,  4.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 10/323 [00:02<01:15,  4.15it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 11/323 [00:02<01:17,  4.03it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▎         | 12/323 [00:02<01:16,  4.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 13/323 [00:03<01:15,  4.08it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 14/323 [00:03<01:14,  4.14it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 15/323 [00:03<01:14,  4.15it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 16/323 [00:03<01:13,  4.17it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▌         | 17/323 [00:04<01:13,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 18/323 [00:04<01:12,  4.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 19/323 [00:04<01:12,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 20/323 [00:04<01:12,  4.18it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 21/323 [00:05<01:12,  4.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 22/323 [00:05<01:12,  4.16it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 23/323 [00:05<01:13,  4.10it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 24/323 [00:05<01:16,  3.91it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 25/323 [00:06<01:15,  3.93it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 26/323 [00:06<01:14,  3.97it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 27/323 [00:06<01:13,  4.02it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▊         | 28/323 [00:06<01:11,  4.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 29/323 [00:07<01:13,  4.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         |
/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  95%|█████████▌| 308/323 [01:22<00:03,  4.02it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  96%|█████████▌| 309/323 [01:22<00:03,  3.92it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  96%|█████████▌| 310/323 [01:22<00:03,  3.79it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  96%|█████████▋| 311/323 [01:23<00:03,  3.36it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 312/323 [01:23<00:03,  3.33it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 313/323 [01:23<00:03,  3.20it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  97%|█████████▋| 314/323 [01:24<00:02,  3.26it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 315/323 [01:24<00:02,  3.36it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 316/323 [01:24<00:02,  3.50it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 317/323 [01:24<00:01,  3.44it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  98%|█████████▊| 318/323 [01:25<00:01,  3.48it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▉| 319/323 [01:25<00:01,  3.60it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▉| 320/323 [01:25<00:00,  3.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  99%|█████████▉| 321/323 [01:25<00:00,  3.85it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# 100%|█████████▉| 322/323 [01:26<00:00,  3.89it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1323498115.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
# 100%|██████████| 323/323 [01:26<00:00,  3.74it/s]

# %%
df.head()
# Out:
#    index                            id_lokalid  \
# 0      0  0a3f50a2-facc-32b8-e044-0003ba298018
# 1      1  2d5f65ce-fb97-4d79-ad1f-7e53cac22667
# 2      2  0a3f50a3-3408-32b8-e044-0003ba298018
# 3      3  0a3f50a3-1359-32b8-e044-0003ba298018
# 4      4  2e350495-4b1f-45b2-9bd0-acf015bd039e
#
#                               husnummer
# 0  0a3f507b-67d8-32b8-e044-0003ba298018
# 1  0a3f507b-7635-32b8-e044-0003ba298018
# 2  0a3f507b-88f9-32b8-e044-0003ba298018
# 3  0a3f507b-739d-32b8-e044-0003ba298018
# 4  0a3f507b-8412-32b8-e044-0003ba298018

# %%
fejl.shape
# Out:
# (25, 1)

# %%
csv, df = BBR_api(df_besp)
# Out:
#   0%|          | 0/323 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   0%|          | 1/323 [00:00<01:28,  3.65it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 2/323 [00:00<01:46,  3.02it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 3/323 [00:00<01:34,  3.38it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   1%|          | 4/323 [00:01<01:40,  3.19it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 5/323 [00:01<01:33,  3.42it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 6/323 [00:01<01:42,  3.11it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 7/323 [00:02<01:35,  3.32it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   2%|▏         | 8/323 [00:02<01:31,  3.46it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 9/323 [00:02<01:28,  3.57it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 10/323 [00:02<01:26,  3.62it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   3%|▎         | 11/323 [00:03<01:23,  3.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▎         | 12/323 [00:03<01:23,  3.73it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 13/323 [00:03<01:21,  3.81it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   4%|▍         | 14/323 [00:03<01:23,  3.71it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 15/323 [00:04<01:22,  3.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▍         | 16/323 [00:04<01:24,  3.65it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   5%|▌         | 17/323 [00:04<01:20,  3.78it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 18/323 [00:05<01:23,  3.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 19/323 [00:05<01:21,  3.72it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   6%|▌         | 20/323 [00:05<01:27,  3.47it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 21/323 [00:05<01:26,  3.49it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 22/323 [00:06<01:28,  3.40it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 23/323 [00:06<01:27,  3.43it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   7%|▋         | 24/323 [00:06<01:37,  3.06it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 25/323 [00:07<01:37,  3.05it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 26/323 [00:07<01:32,  3.21it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   8%|▊         | 27/323 [00:07<01:38,  3.01it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▊         | 28/323 [00:08<01:50,  2.66it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 29/323 [00:08<01:57,  2.51it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#   9%|▉         | 30/323 [00:09<01:51,  2.64it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|▉         | 31/323 [00:09<01:40,  2.89it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%|▉         | 32/323 [00:09<01:44,  2.78it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\1450996751.py:60: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   chunk = pd.read_sql(query, con=conn)
#  10%
# 14   2688.0            421
# 15   1100.0            441
# 16   1100.0            441
# 17   1100.0            441
# 18      NaN            NaN
# 19    221.0            531
# 20     96.0            449
# 21    148.0            590
# 22      NaN            NaN
# 23      NaN            NaN
# 24    167.0            590
# 25      NaN            NaN
# 26    750.0            412
# 27      NaN            NaN
# 28      NaN            NaN
# 29    796.0            441
# 30     99.0            531
# 31      NaN            NaN
# 32    121.0            450
# 33    160.0            590
# 34    123.0            590
# 35    428.0            441
# 36      NaN            NaN
# 37   1467.0            441
# 38   1690.0            160
# 39   3576.0            429
# 40     96.0            530
# 41    448.0            441
# 42    474.0            441
# 43    551.0            590
# 44    878.0            219
# 45   5173.0            219
# 46    140.0            590
# 47    804.0            441
# 48   1060.0            590
# 49    159.0            350

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data = pd.read_csv('../MeteringPoints.csv', sep=';')
data2 = pd.read_csv('../Meterdata.csv', sep=';')
data = data.merge(data2)
data = data[['MålepunktsID', 'Juridisk_kontakt_By', 'Fra_dato', 'Til_dato', 'Mængde']]
data.columns = ['meter', 'Adresse', 'from', 'to', 'amount']
data['from'] = pd.to_datetime(data['from'])
#data['amount'] = pd.to_numeric(data['amount'])
data['day-moment'] = data['from'].dt.hour.map(get_day_moment)

data.head()
# Out:
#                 meter  Adresse                from                to  amount  \
# 0  571313123200330480  Mårslet 2019-04-19 00:00:00  19-04-2019 01:00    0.08
# 1  571313123200330480  Mårslet 2019-04-19 01:00:00  19-04-2019 02:00    0.07
# 2  571313123200330480  Mårslet 2019-04-19 02:00:00  19-04-2019 03:00    0.06
# 3  571313123200330480  Mårslet 2019-04-19 03:00:00  19-04-2019 04:00    0.07
# 4  571313123200330480  Mårslet 2019-04-19 04:00:00  19-04-2019 05:00    0.05
#
#   day-moment
# 0      night
# 1      night
# 2      night
# 3      night
# 4      night

# %%
df = data
df_besp, dff = besp()
dff['meter'] = pd.to_numeric(dff['meter'])
kunde = 'Privat_elforbrug_test'
df_besp.head()
dff = dff.iloc[889:]
dff.head()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]C:\Users\misc\AppData\Local\Temp\ipykernel_26464\2830085382.py:80: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dff = df.groupby([df['from'].dt.day_name(locale='da_DK'), df['from'].dt.hour]).mean().reset_index(names=['day', 'hour'])
# C:\Users\misc\AppData\Local\Temp\ipykernel_26464\2830085382.py:80: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dff = df.groupby([df['from'].dt.day_name(locale='da_DK'), df['from'].dt.hour]).mean().reset_index(names=['day', 'hour'])
# C:\Users\misc\AppData\Local\Temp\ipykernel_26464\2830085382.py:169: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_besp = df_besp.append(ttt)
# C:\Users\misc\AppData\Local\Temp\ipykernel_26464\2830085382.py:170: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfff = dfff.append(dff)
# 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]
#                    from         meter  amount day-moment  Adresse     bkps
# 889 2019-04-24 00:00:00  5.713131e+17    0.08      night  Mårslet  0.96978
# 890 2019-04-24 01:00:00  5.713131e+17    0.07      night  Mårslet  0.96978
# 891 2019-04-24 02:00:00  5.713131e+17    0.07      night  Mårslet  0.96978
# 892 2019-04-24 03:00:00  5.713131e+17    0.07      night  Mårslet  0.96978
# 893 2019-04-24 04:00:00  5.713131e+17    0.10      night  Mårslet  0.96978
